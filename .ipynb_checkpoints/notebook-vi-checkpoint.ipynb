# %% [markdown]
# # Tìm thể loại ứng dụng có khả năng sinh lời trên Google Play và App Store
#
# Giả định rằng tôi đang làm việc cho một công ty thiết kế ứng dụng di động. Doanh thu của công ty đến từ quảng cáo bên trong ứng dụng miễn phí. Mục tiêu của chúng ta là phân tích và giúp các nhà phát triển tìm ra các thể loại ứng dụng thu hút nhiều người dùng.
#
# Tôi đã sử dụng 2 tệp dữ liệu về ứng dụng trên Google Play và App Store được chia sẻ trên Kaggle để phân tích. Tôi sẽ làm sạch dữ liệu, phân tích xem thể loại ứng dụng nào chiếm tỷ lệ nhiều nhất, có nhiều lượt cài đặt và đánh giá nhất để đưa ra các đề xuất.
#
# **Tóm tắt kết quả**
#
# Kết quả là tôi đã tìm được 6 thể loại ứng dụng thu hút người dùng nhất (Video or Music, Photography, Book, Productivity, Game, Tools) và gợi ý cụ thể một vài ứng dụng cho các thể loại này.

# %% [markdown]
# ## Khám phá các tệp dữ liệu
#
# - **Dữ liệu ứng dụng trên Google Play:** [Xem trên Kaggle](https://www.kaggle.com/lava18/google-play-store-apps), bạn có thể lại nó [tại đây](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv).
# - **Dữ liệu ứng dụng trên App Store:** [Xem trên Kaggle](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps), bạn có thể tải nó [tại đây](https://dq-content.s3.amazonaws.com/350/AppleStore.csv).
#
# Khi đọc bình luận trên 2 tệp dữ liệu này, chúng ta thấy rằng trong tệp dữ liệu Google Play có [lỗi sai thông tin dữ liệu ở dòng 10472](https://www.kaggle.com/lava18/google-play-store-apps/discussion/66015) và [lỗi trùng lặp dữ liệu](https://www.kaggle.com/lava18/google-play-store-apps/discussion/67894).
#
# Như vậy công việc làm sạch dữ liệu của chúng ta sẽ có thêm việc xử lý 2 lỗi này. Bây giờ hãy cùng tôi khám phá 2 tệp dữ liệu này nhé.

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

# %%
# Explore Android dataset
df_android = pd.read_csv('googleplaystore.csv')
print(df_android.shape)
df_android.head(2)
# Out:
# (10841, 13)
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# Dữ liệu từ Google Play (Android) có 10841 dòng và 13 cột. Tên của các cột này khá rõ ràng để giúp chúng ta hiểu được dữ liệu của chúng (App, Category, Rating, Reviews, Size, Installs, Type, Price,...).

# %%
# Explore IOS dataset
df_ios = pd.read_csv('AppleStore.csv')
print(df_ios.shape)
df_ios.head(2)
# Out:
# (7197, 16)
#           id track_name  size_bytes currency  price  rating_count_tot  \
# 0  284882215   Facebook   389879808      USD    0.0           2974676
# 1  389801252  Instagram   113954816      USD    0.0           2161558
#
#    rating_count_ver  user_rating  user_rating_ver    ver cont_rating  \
# 0               212          3.5              3.5   95.0          4+
# 1              1289          4.5              4.0  10.23         12+
#
#          prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0  Social Networking               37                1        29        1
# 1      Photo & Video               37                0        29        1

# %% [markdown]
# Dữ liệu từ App Store (IOS) có 7197 dòng và 16 cột. Một số cột có tên dễ hiểu để sử dụng (track_name, size_bytes, currency, price, rating_count_tot, prime_genre) và một số cột khác có tên chưa rõ ràng nhưng chúng ta có thể [tìm hiểu chúng](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/home) khi cần thiết.

# %% [markdown]
# ## Xóa dữ liệu bị sai
#
# Theo [bình luận trên Kaggle](https://www.kaggle.com/lava18/google-play-store-apps/discussion/66015) thì dữ liệu ứng dụng Google Play có 1 dòng bị sai thông tin (10472). Nhưng để biết chính xác dòng 10472 là ở dataset có tính header hay không thì chúng ta phải tự kiểm tra.

# %%
# Check wrong data 10472
df_android[10472:10473]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# Như vậy dữ liệu Google Play bị sai ở dòng 10472 do thiếu Category. Bây giờ chúng ta sẽ xóa dòng này.

# %%
# Delete wrong data 10472
df_android.drop(index=10472, inplace=True)

# %%
df_android.shape
# Out:
# (10840, 13)

# %% [markdown]
# ## Xóa dữ liệu bị trùng lặp
# Trước khi xóa dữ liệu trùng lặp, chúng ta nên kiểm tra xem chúng trùng lặp như thế thế nào.

# %%
# Check duplicated Android
df_android_dup = df_android[df_android.App.duplicated(keep=False) == True].sort_values(by='App')
print(df_android_dup.shape)
df_android_dup.head()
# Out:
# (1979, 13)
#                              App            Category  Rating Reviews  Size  \
# 1393       10 Best Foods for You  HEALTH_AND_FITNESS     4.0    2490  3.8M
# 1407       10 Best Foods for You  HEALTH_AND_FITNESS     4.0    2490  3.8M
# 2543  1800 Contacts - Lens Store             MEDICAL     4.7   23160   26M
# 2322  1800 Contacts - Lens Store             MEDICAL     4.7   23160   26M
# 2385  2017 EMRA Antibiotic Guide             MEDICAL     4.4      12  3.8M
#
#         Installs  Type   Price Content Rating            Genres  \
# 1393    500,000+  Free       0   Everyone 10+  Health & Fitness
# 1407    500,000+  Free       0   Everyone 10+  Health & Fitness
# 2543  1,000,000+  Free       0       Everyone           Medical
# 2322  1,000,000+  Free       0       Everyone           Medical
# 2385      1,000+  Paid  $16.99       Everyone           Medical
#
#            Last Updated Current Ver   Android Ver
# 1393  February 17, 2017         1.9  2.3.3 and up
# 1407  February 17, 2017         1.9  2.3.3 and up
# 2543      July 27, 2018       7.4.1    5.0 and up
# 2322      July 27, 2018       7.4.1    5.0 and up
# 2385   January 27, 2017       1.0.5  4.0.3 and up

# %%
# Check duplicated IOS
df_ios_dup = df_ios[df_ios.track_name.duplicated(keep=False) == True].sort_values(by='track_name')
print(df_ios_dup.shape)
df_ios_dup.head()
# Out:
# (4, 16)
#               id           track_name  size_bytes currency  price  \
# 2948  1173990889  Mannequin Challenge   109705216      USD    0.0
# 4463  1178454060  Mannequin Challenge    59572224      USD    0.0
# 4442   952877179    VR Roller Coaster   169523200      USD    0.0
# 4831  1089824278    VR Roller Coaster   240964608      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 2948               668                87          3.0              3.0    1.4
# 4463               105                58          4.0              4.5  1.0.1
# 4442               107               102          3.5              3.5  2.0.0
# 4831                67                44          3.5              4.0   0.81
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 2948          9+       Games               37                4         1
# 4463          4+       Games               38                5         1
# 4442          4+       Games               37                5         1
# 4831          4+       Games               38                0         1
#
#       vpp_lic
# 2948        1
# 4463        1
# 4442        1
# 4831        1

# %% [markdown]
# Như vậy chỉ có Google Play bị trùng lặp 1979 dòng và IOS bị trùng lặp 4 dòng. Bây giờ chúng ta kiểm tra chi tiết hơn với một ứng dụng bất kỳ như `8 Ball Pool` bên Android để xem chúng có hoàn toàn giống nhau 100% hay không.

# %%
# View duplicate 8 Ball Pool Android
df_android_dup[df_android_dup.App == '8 Ball Pool']
# Out:
#               App Category  Rating   Reviews Size      Installs  Type Price  \
# 3953  8 Ball Pool   SPORTS     4.5  14184910  52M  100,000,000+  Free     0
# 1970  8 Ball Pool     GAME     4.5  14201604  52M  100,000,000+  Free     0
# 1844  8 Ball Pool     GAME     4.5  14200550  52M  100,000,000+  Free     0
# 1755  8 Ball Pool     GAME     4.5  14200344  52M  100,000,000+  Free     0
# 1703  8 Ball Pool     GAME     4.5  14198602  52M  100,000,000+  Free     0
# 1675  8 Ball Pool     GAME     4.5  14198297  52M  100,000,000+  Free     0
# 1871  8 Ball Pool     GAME     4.5  14201891  52M  100,000,000+  Free     0
#
#      Content Rating  Genres   Last Updated Current Ver   Android Ver
# 3953       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1970       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1844       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1755       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1703       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1675       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1871       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up

# %% [markdown]
# Chúng ta thấy rằng các dòng này có sự khác nhau ở cột `Reviews`. Theo logic thì các giá trị cao nhất có thể là dữ mới nhất được cập nhật, tương tự nhìn lại bên IOS là cột `rating_count_tot`. Vì vậy chúng ta nên giữ lại dòng có reviews cao nhất và xóa các dòng bị trùng lặp còn lại.
#
# ### Xóa dữ liệu trùng lặp Android

# %%
# Change type Reviews column
df_android_dup.Reviews = df_android_dup.Reviews.astype(int)
df_android.Reviews = df_android.Reviews.astype(int)

# %%
# Find the maximum reivews of each app
df_android_reviews_max = df_android.groupby('App')['Reviews'].max().reset_index()
df_android_reviews_max
# Out:
#                                                    App  Reviews
# 0                 "i DT" Fútbol. Todos Somos Técnicos.       27
# 1                        +Download 4 Instagram Twitter    40467
# 2                           - Free Comics - Comic Apps      115
# 3                                                   .R      259
# 4                                               /u/app      573
# ...                                                ...      ...
# 9654                           뽕티비 - 개인방송, 인터넷방송, BJ방송      414
# 9655                                        💎 I'm rich      718
# 9656     💘 WhatsLov: Smileys of love, stickers and GIF    22098
# 9657  📏 Smart Ruler ↔️ cm/inch measuring for homework!       19
# 9658  🔥 Football Wallpapers 4K | Full HD Backgrounds 😍    11661
#
# [9659 rows x 2 columns]

# %%
# Remove duplicated apps for android
df_android_reviews_merge = pd.merge(df_android_reviews_max, df_android, on=['App','Reviews'], how='left').drop_duplicates().reset_index(drop=True)
print(df_android_reviews_merge.shape)
df_android_reviews_merge.head()
# Out:
# (9665, 13)
#                                     App  Reviews       Category  Rating  Size  \
# 0  "i DT" Fútbol. Todos Somos Técnicos.       27         SPORTS     NaN  3.6M
# 1         +Download 4 Instagram Twitter    40467         SOCIAL     4.5   22M
# 2            - Free Comics - Comic Apps      115         COMICS     3.5  9.1M
# 3                                    .R      259          TOOLS     4.5  203k
# 4                                /u/app      573  COMMUNICATION     4.7   53M
#
#      Installs  Type Price Content Rating         Genres        Last Updated  \
# 0        500+  Free     0       Everyone         Sports     October 7, 2017
# 1  1,000,000+  Free     0       Everyone         Social      August 2, 2018
# 2     10,000+  Free     0     Mature 17+         Comics       July 13, 2018
# 3     10,000+  Free     0       Everyone          Tools  September 16, 2014
# 4     10,000+  Free     0     Mature 17+  Communication        July 3, 2018
#
#   Current Ver Android Ver
# 0        0.22  4.1 and up
# 1        5.03  4.1 and up
# 2      5.0.12  5.0 and up
# 3      1.1.06  1.5 and up
# 4       4.2.4  4.1 and up

# %% [markdown]
# So sánh số dòng của `df_android_reviews_merge` và `df_android_reviews_max` ta thấy có sự khác nhau (9665 và 9659). Như vậy vẫn còn vài ứng dụng trùng lặp, chúng ta sẽ kiểm tra thế nào.

# %%
df_android_dup_2 = df_android_reviews_merge[df_android_reviews_merge.App.duplicated(keep=False) == True].sort_values(by='App').reset_index(drop=True)
df_android_dup_2
# Out:
#                                        App  Reviews       Category  Rating  \
# 0                               Candy Bomb    42145           GAME     4.4
# 1                               Candy Bomb    42145         FAMILY     4.4
# 2   Fuzzy Numbers: Pre-K Number Foundation       21      EDUCATION     4.7
# 3   Fuzzy Numbers: Pre-K Number Foundation       21         FAMILY     4.7
# 4                                Learn C++    73404      EDUCATION     4.6
# 5                                Learn C++    73404         FAMILY     4.6
# 6              Target - now with Cartwheel    68406       SHOPPING     4.1
# 7              Target - now with Cartwheel    68406       SHOPPING     4.1
# 8                           YouTube Gaming   130549  ENTERTAINMENT     4.2
# 9                           YouTube Gaming   130549         FAMILY     4.2
# 10                 osmino Wi-Fi: free WiFi   134203          TOOLS     4.2
# 11                 osmino Wi-Fi: free WiFi   134203          TOOLS     4.2
#
#                   Size     Installs  Type  Price Content Rating  \
# 0                  20M  10,000,000+  Free      0       Everyone
# 1                  20M  10,000,000+  Free      0       Everyone
# 2                  44M       1,000+  Paid  $5.99       Everyone
# 3                  44M       1,000+  Paid  $5.99       Everyone
# 4                 5.3M   1,000,000+  Free      0       Everyone
# 5                 5.3M   1,000,000+  Free      0       Everyone
# 6                  24M  10,000,000+  Free      0       Everyone
# 7                  24M  10,000,000+  Free      0       Everyone
# 8   Varies with device   5,000,000+  Free      0           Teen
# 9   Varies with device   5,000,000+  Free      0           Teen
# 10                4.1M  10,000,000+  Free      0       Everyone
# 11                4.1M  10,000,000+  Free      0       Everyone
#
#                  Genres       Last Updated        Current Ver   Android Ver
# 0    Casual;Brain Games       July 4, 2018           2.9.3181  4.0.3 and up
# 1    Casual;Brain Games       July 4, 2018           2.9.3181  4.0.3 and up
# 2   Education;Education      July 21, 2017                1.3    4.1 and up
# 3   Education;Education      July 21, 2017                1.3    4.1 and up
# 4             Education  December 25, 2017              4.5.2    4.0 and up
# 5             Education  December 25, 2017              4.5.2    4.0 and up
# 6              Shopping      July 25, 2018  6.25.0+1906001476    5.0 and up
# 7              Shopping     August 6, 2018  6.25.0+1906001476    5.0 and up
# 8         Entertainment      June 27, 2018          2.08.78.2    4.1 and up
# 9         Entertainment      June 27, 2018          2.08.78.2    4.1 and up
# 10                Tools     August 6, 2018            6.06.14    4.4 and up
# 11                Tools     August 7, 2018            6.06.14    4.4 and up

# %% [markdown]
# Mặc dù `Reviews` đúng số lớn nhất nhưng các dòng trùng lặp có sự khác nhau ở `Category` và `Last Updated`. Cách xử lý như sau:
# - Giữ lại `Last Updated` mới nhất.
# - Giữ lại `Category` có trong `Genres`.

# %%
# Change type of Last Updated to datetime
df_android_dup_2['Last Updated'] = pd.to_datetime(df_android_dup_2['Last Updated'])
df_android_reviews_merge['Last Updated'] = pd.to_datetime(df_android_reviews_merge['Last Updated'])

# %%
# Find the last updated
df_android_updated_max = df_android_dup_2.groupby('App')['Last Updated'].max().reset_index()
df_android_updated_max
# Out:
#                                       App Last Updated
# 0                              Candy Bomb   2018-07-04
# 1  Fuzzy Numbers: Pre-K Number Foundation   2017-07-21
# 2                               Learn C++   2017-12-25
# 3             Target - now with Cartwheel   2018-08-06
# 4                          YouTube Gaming   2018-06-27
# 5                 osmino Wi-Fi: free WiFi   2018-08-07

# %%
# Remove duplicated apps
df_android_dup_2_removed = pd.merge(df_android_updated_max, df_android_dup_2, on=['App','Last Updated'], how='left')
df_android_dup_2_removed.Genres = df_android_dup_2_removed.Genres.str.upper()
df_android_dup_2_removed = df_android_dup_2_removed[df_android_dup_2_removed.apply(lambda x : x['Category'] in x['Genres'], axis=1)]
df_android_dup_2_removed
# Out:
#                                       App Last Updated  Reviews  \
# 0                              Candy Bomb   2018-07-04    42145
# 2  Fuzzy Numbers: Pre-K Number Foundation   2017-07-21       21
# 4                               Learn C++   2017-12-25    73404
# 6             Target - now with Cartwheel   2018-08-06    68406
# 7                          YouTube Gaming   2018-06-27   130549
# 9                 osmino Wi-Fi: free WiFi   2018-08-07   134203
#
#         Category  Rating                Size     Installs  Type  Price  \
# 0           GAME     4.4                 20M  10,000,000+  Free      0
# 2      EDUCATION     4.7                 44M       1,000+  Paid  $5.99
# 4      EDUCATION     4.6                5.3M   1,000,000+  Free      0
# 6       SHOPPING     4.1                 24M  10,000,000+  Free      0
# 7  ENTERTAINMENT     4.2  Varies with device   5,000,000+  Free      0
# 9          TOOLS     4.2                4.1M  10,000,000+  Free      0
#
#   Content Rating               Genres        Current Ver   Android Ver
# 0       Everyone   CASUAL;BRAIN GAMES           2.9.3181  4.0.3 and up
# 2       Everyone  EDUCATION;EDUCATION                1.3    4.1 and up
# 4       Everyone            EDUCATION              4.5.2    4.0 and up
# 6       Everyone             SHOPPING  6.25.0+1906001476    5.0 and up
# 7           Teen        ENTERTAINMENT          2.08.78.2    4.1 and up
# 9       Everyone                TOOLS            6.06.14    4.4 and up

# %%
# Create removed duplicated apps name list
df_android_dup_2_name = df_android_dup_2_removed.App.values.tolist()

# %%
# Filter and combine to get the Android unique apps
df_android_unique = pd.concat([df_android_reviews_merge.query('App not in @df_android_dup_2_name'), df_android_dup_2_removed])
print(df_android_unique.shape)
df_android_unique.head(2)
# Out:
# (9659, 13)
#                                     App  Reviews Category  Rating  Size  \
# 0  "i DT" Fútbol. Todos Somos Técnicos.       27   SPORTS     NaN  3.6M
# 1         +Download 4 Instagram Twitter    40467   SOCIAL     4.5   22M
#
#      Installs  Type Price Content Rating  Genres Last Updated Current Ver  \
# 0        500+  Free     0       Everyone  Sports   2017-10-07        0.22
# 1  1,000,000+  Free     0       Everyone  Social   2018-08-02        5.03
#
#   Android Ver
# 0  4.1 and up
# 1  4.1 and up

# %% [markdown]
# ### Xóa dữ liệu trùng lặp IOS

# %% [markdown]
# Với IOS thì chỉ có 2 ứng dụng bị trùng lặp, ta sẽ xóa những dòng có số lượng rating thấp hơn theo index của chúng.

# %%
df_ios_unique = df_ios.drop(index=[4463,4831])
df_ios_unique.shape
# Out:
# (7195, 16)

# %% [markdown]
# ## Lọc ra các ứng dụng ngôn ngữ tiếng Anh
# Công ty của tôi chỉ nhắm đến người dùng sử dụng ngôn ngữ tiếng Anh mà thôi. Vì vậy chúng ta phải loại bỏ các ứng dụng có tên không phải là tiếng Anh.
#
# Theo [ASCII - Wikipedia](https://en.wikipedia.org/wiki/ASCII) (American Standard Code for Information Interchange) thì có 127 ký tự trong tiếng Anh, chúng bao gồm các chữ cái (a,A,b,B,c,C,...) và các ký tự thông dụng trên bàn phím (+,-,@,!,~,...). Chúng ta sẽ dùng hàm `ord('string')` trong Python để xử lý vấn đề này.

# %%
# Check English name
def is_english(app_name):
    for i in app_name:
        if ord(i) > 127:
            return False
    return True

print(is_english('Instachat 😜'))
print(is_english('Facebook'))
print(is_english('Official QR Code® Reader "Q"'))
print(is_english('RPG ブレイジング ソウルズ アクセレイト'))
# Out:
# False
# True
# False
# False

# %% [markdown]
# Funtion này đã giúp chúng ta xác định được tên của ứng dụng có phải tiếng Anh hay không. Tuy nhiên, có một số ứng dụng chỉ chứa 1-2 ký tự nằm ngoài ASCII (Ví dụ: Instachat 😜), nếu chúng ta loại bỏ chúng thì sẽ mất một lượng dữ liệu hưu ích. Vì vậy, chúng ta sẽ chấp nhận các ứng có không quá 3 ký tự nàm ngoài ASCII trong tên của chúng.

# %%
# Check English name - allow 3 characters outside of ASCII
def is_english(app_name):
    non_ascii = 0
    for i in app_name:
        if ord(i) > 127:
            non_ascii += 1
    if non_ascii > 3:
        return False
    else:
        return True

print(is_english('Instachat 😜'))
print(is_english('Facebook'))
print(is_english('Official QR Code® Reader "Q"'))
print(is_english('RPG ブレイジング ソウルズ アクセレイト'))
# Out:
# True
# True
# True
# False

# %% [markdown]
# Function này đã tốt hơn. Bây giờ chúng ta sẽ tạo 2 danh sách ứng dụng mới chỉ có tên tiếng Anh cho Android và IOS.

# %%
# Create 2 english apps dataframes for Android and IOS
df_android_english = df_android_unique[df_android_unique.apply(lambda x : is_english(x.App), axis=1)]
df_ios_english = df_ios_unique[df_ios_unique.apply(lambda x : is_english(x.track_name), axis=1)]

# %% [markdown]
# ## Lọc ra các ứng dụng ngôn ngữ tiếng Anh "miễn phí"
#
# Doanh thu của công ty đến từ quảng cáo bên trong các ứng dụng miễn phí. Vì vậy chúng ta cần lọc ra các ứng dụng miễn để phân tích.

# %%
# Create Androis english free (final)
df_android_english_free = df_android_english[df_android_english.Price == '0']
print(df_android_english_free.shape)
df_android_english_free.head(2)
# Out:
# (8864, 13)
#                                     App  Reviews Category  Rating  Size  \
# 0  "i DT" Fútbol. Todos Somos Técnicos.       27   SPORTS     NaN  3.6M
# 1         +Download 4 Instagram Twitter    40467   SOCIAL     4.5   22M
#
#      Installs  Type Price Content Rating  Genres Last Updated Current Ver  \
# 0        500+  Free     0       Everyone  Sports   2017-10-07        0.22
# 1  1,000,000+  Free     0       Everyone  Social   2018-08-02        5.03
#
#   Android Ver
# 0  4.1 and up
# 1  4.1 and up

# %%
# Create IOS english free (final)
df_ios_english_free = df_ios_english[df_ios_english.price == 0]
print(df_ios_english_free.shape)
df_ios_english_free.head(2)
# Out:
# (3220, 16)
#           id track_name  size_bytes currency  price  rating_count_tot  \
# 0  284882215   Facebook   389879808      USD    0.0           2974676
# 1  389801252  Instagram   113954816      USD    0.0           2161558
#
#    rating_count_ver  user_rating  user_rating_ver    ver cont_rating  \
# 0               212          3.5              3.5   95.0          4+
# 1              1289          4.5              4.0  10.23         12+
#
#          prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0  Social Networking               37                1        29        1
# 1      Photo & Video               37                0        29        1

# %% [markdown]
# Công việc làm sạch dữ liệu đã hoàn tất. Bây giờ chúng ta sẽ tiến hành phân tích.
#
# ## Phân tích các thể loại ứng dụng phổ biến
#
# Chúng ta sẽ phân tích tỷ lệ các thể loại ứng dụng để xem mức độ cạnh tranh như thế nào. Cả 2 tệp dữ liệu đều có các cột giúp chúng ta làm được việc này.
#
# - **Google Play:** Category, Genres
# - **App Store:** prime_genre

# %% [markdown]
# ### Android
# Cột Category thể hiện chính xác hơn tỷ lệ cho từng thể loại, còn cột Genres đang gộp nhiều thể loại với nhau (Ví dụ: Educational;Brain Games và Entertainment;Brain Games). Vì vậy chúng ta sẽ chỉ dùng cột Category để phân tích về sau.

# %%
# Calculate Android categories proportion
pd.DataFrame(round((df_android_english_free.Category.value_counts()/df_android_english_free.shape[0])*100,2)).set_axis(['Proportion'],axis=1)
# Out:
#                      Proportion
# FAMILY                    18.91
# GAME                       9.72
# TOOLS                      8.46
# BUSINESS                   4.59
# LIFESTYLE                  3.90
# PRODUCTIVITY               3.89
# FINANCE                    3.70
# MEDICAL                    3.53
# SPORTS                     3.40
# PERSONALIZATION            3.32
# COMMUNICATION              3.24
# HEALTH_AND_FITNESS         3.08
# PHOTOGRAPHY                2.94
# NEWS_AND_MAGAZINES         2.80
# SOCIAL                     2.66
# TRAVEL_AND_LOCAL           2.34
# SHOPPING                   2.25
# BOOKS_AND_REFERENCE        2.14
# DATING                     1.86
# VIDEO_PLAYERS              1.79
# MAPS_AND_NAVIGATION        1.40
# FOOD_AND_DRINK             1.24
# EDUCATION                  1.16
# ENTERTAINMENT              0.96
# LIBRARIES_AND_DEMO         0.94
# AUTO_AND_VEHICLES          0.93
# HOUSE_AND_HOME             0.82
# WEATHER                    0.80
# EVENTS                     0.71
# PARENTING                  0.65
# ART_AND_DESIGN             0.64
# COMICS                     0.62
# BEAUTY                     0.60

# %% [markdown]
# - Thể loại ứng dụng chiếm tỷ lệ lớn nhất là FAMILY (18.91%), kế đến là GAME (9.72%), TOOLS (8.46%), BUSINESS (4.59%) VÀ LIFESTYLE (3.90%).
# - Khi [kiểm tra trên website Google Play](https://play.google.com/store/apps/category/FAMILY) thì chúng ta thấy rằng thể loại FAMILY thực chất là những trò chơi dành cho trẻ em.

# %% [markdown]
# ![FAMILY](attachment:Screen%20Shot%202021-11-10%20at%2020.54.32.png)

# %% [markdown]
# ### IOS

# %%
# Calculate IOS genres proportion
pd.DataFrame(round((df_ios_english_free.prime_genre.value_counts()/df_ios_english_free.shape[0])*100,2)).set_axis(['Proportion'],axis=1)
# Out:
#                    Proportion
# Games                   58.14
# Entertainment            7.89
# Photo & Video            4.97
# Education                3.66
# Social Networking        3.29
# Shopping                 2.61
# Utilities                2.52
# Sports                   2.14
# Music                    2.05
# Health & Fitness         2.02
# Productivity             1.74
# Lifestyle                1.58
# News                     1.34
# Travel                   1.24
# Finance                  1.12
# Weather                  0.87
# Food & Drink             0.81
# Reference                0.56
# Business                 0.53
# Book                     0.43
# Navigation               0.19
# Medical                  0.19
# Catalogs                 0.12

# %% [markdown]
# - Thể loại chiếm tỷ lệ lớn nhất là Games (58.14%), kế đến là Entertaiment (7.89%), Photo & Video (4.97%), Education (3.66%) và Social Networking (3.29%).
# - Nhìn chung ứng dụng miễn phí trên App Store mang tính giải trí nhiều hơn, riêng thể loại Games đã chiếm hơn 50%.

# %% [markdown]
# ### Kết luận
#
# Qua việc phân tích tỷ lệ các thể loại ứng dụng trên Google Play và App Store, chúng ta kết luận rằng phần lớn ứng dụng trên Google Play và App Store là ứng dụng giải trí. Nhưng Google Play có sự cân bằng hơn giữa ứng dụng giải trí và ứng dụng liên quan đời sống thực tế.
#
# Để giảm mức độ cạnh tranh, chúng ta không nên phát triển ứng dụng Game vì có quá nhiều đối thủ (App Store hơn 58.16% là Game), thị trường Game đang bão hòa.
#
# ## Phân tích số lượng người dùng trung bình

# %% [markdown]
# Mục tiêu của chúng ta là tìm ra thể loại ứng dụng thu hút được nhiều người dùng nhất. Vì vậy chúng ta cần phân tích xem số lượng người dùng trung bình của mỗi thể loại ứng dụng là bao nhiêu.
#
# - **Google Play:** Installs
# - **App Store:** rating_count_tot, bởi vì App Store không có dữ liệu về lượt cài đặt nên chúng ta dùng rating_count_tot để thay thế.
#
# *Note: Lý do mà tôi không dùng 'Tổng số lượng người dùng' để phân tích vì để tránh trường hợp có một vài ứng dụng quá xuất sắc ảnh hưởng đến nhận xét sai về một thể loại.*
#
# ### Số lượng người dùng trung bình mỗi thể loại trên Android

# %%
# Convert Installs column to number
df_android_english_free.Installs = df_android_english_free.Installs.str.replace('+','').str.replace(',','').astype(int)

# %%
# Calculate average installs of each category for Android
pd.DataFrame(round(df_android_english_free.groupby('Category')['Installs'].sum() / df_android_english_free.Category.value_counts())).sort_values(by=0, ascending=False).set_axis(['Average installs'],axis=1).style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_acd02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acd02_level0_col0" class="col_heading level0 col0" >Average installs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acd02_level0_row0" class="row_heading level0 row0" >COMMUNICATION</th>
#       <td id="T_acd02_row0_col0" class="data row0 col0" >38,456,119</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row1" class="row_heading level0 row1" >VIDEO_PLAYERS</th>
#       <td id="T_acd02_row1_col0" class="data row1 col0" >24,727,872</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row2" class="row_heading level0 row2" >SOCIAL</th>
#       <td id="T_acd02_row2_col0" class="data row2 col0" >23,253,652</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row3" class="row_heading level0 row3" >PHOTOGRAPHY</th>
#       <td id="T_acd02_row3_col0" class="data row3 col0" >17,840,110</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row4" class="row_heading level0 row4" >PRODUCTIVITY</th>
#       <td id="T_acd02_row4_col0" class="data row4 col0" >16,787,331</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row5" class="row_heading level0 row5" >GAME</th>
#       <td id="T_acd02_row5_col0" class="data row5 col0" >15,588,016</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row6" class="row_heading level0 row6" >TRAVEL_AND_LOCAL</th>
#       <td id="T_acd02_row6_col0" class="data row6 col0" >13,984,078</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row7" class="row_heading level0 row7" >ENTERTAINMENT</th>
#       <td id="T_acd02_row7_col0" class="data row7 col0" >11,640,706</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row8" class="row_heading level0 row8" >TOOLS</th>
#       <td id="T_acd02_row8_col0" class="data row8 col0" >10,801,391</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row9" class="row_heading level0 row9" >NEWS_AND_MAGAZINES</th>
#       <td id="T_acd02_row9_col0" class="data row9 col0" >9,549,178</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row10" class="row_heading level0 row10" >BOOKS_AND_REFERENCE</th>
#       <td id="T_acd02_row10_col0" class="data row10 col0" >8,767,812</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row11" class="row_heading level0 row11" >SHOPPING</th>
#       <td id="T_acd02_row11_col0" class="data row11 col0" >7,036,877</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row12" class="row_heading level0 row12" >PERSONALIZATION</th>
#       <td id="T_acd02_row12_col0" class="data row12 col0" >5,201,483</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row13" class="row_heading level0 row13" >WEATHER</th>
#       <td id="T_acd02_row13_col0" class="data row13 col0" >5,074,486</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row14" class="row_heading level0 row14" >HEALTH_AND_FITNESS</th>
#       <td id="T_acd02_row14_col0" class="data row14 col0" >4,188,822</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row15" class="row_heading level0 row15" >MAPS_AND_NAVIGATION</th>
#       <td id="T_acd02_row15_col0" class="data row15 col0" >4,056,942</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row16" class="row_heading level0 row16" >FAMILY</th>
#       <td id="T_acd02_row16_col0" class="data row16 col0" >3,695,642</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row17" class="row_heading level0 row17" >SPORTS</th>
#       <td id="T_acd02_row17_col0" class="data row17 col0" >3,638,640</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row18" class="row_heading level0 row18" >ART_AND_DESIGN</th>
#       <td id="T_acd02_row18_col0" class="data row18 col0" >1,986,335</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row19" class="row_heading level0 row19" >FOOD_AND_DRINK</th>
#       <td id="T_acd02_row19_col0" class="data row19 col0" >1,924,898</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row20" class="row_heading level0 row20" >EDUCATION</th>
#       <td id="T_acd02_row20_col0" class="data row20 col0" >1,833,495</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row21" class="row_heading level0 row21" >BUSINESS</th>
#       <td id="T_acd02_row21_col0" class="data row21 col0" >1,712,290</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row22" class="row_heading level0 row22" >LIFESTYLE</th>
#       <td id="T_acd02_row22_col0" class="data row22 col0" >1,437,816</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row23" class="row_heading level0 row23" >FINANCE</th>
#       <td id="T_acd02_row23_col0" class="data row23 col0" >1,387,692</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row24" class="row_heading level0 row24" >HOUSE_AND_HOME</th>
#       <td id="T_acd02_row24_col0" class="data row24 col0" >1,331,541</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row25" class="row_heading level0 row25" >DATING</th>
#       <td id="T_acd02_row25_col0" class="data row25 col0" >854,029</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row26" class="row_heading level0 row26" >COMICS</th>
#       <td id="T_acd02_row26_col0" class="data row26 col0" >817,657</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row27" class="row_heading level0 row27" >AUTO_AND_VEHICLES</th>
#       <td id="T_acd02_row27_col0" class="data row27 col0" >647,318</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row28" class="row_heading level0 row28" >LIBRARIES_AND_DEMO</th>
#       <td id="T_acd02_row28_col0" class="data row28 col0" >638,504</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row29" class="row_heading level0 row29" >PARENTING</th>
#       <td id="T_acd02_row29_col0" class="data row29 col0" >542,604</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row30" class="row_heading level0 row30" >BEAUTY</th>
#       <td id="T_acd02_row30_col0" class="data row30 col0" >513,152</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row31" class="row_heading level0 row31" >EVENTS</th>
#       <td id="T_acd02_row31_col0" class="data row31 col0" >253,542</td>
#     </tr>
#     <tr>
#       <th id="T_acd02_level0_row32" class="row_heading level0 row32" >MEDICAL</th>
#       <td id="T_acd02_row32_col0" class="data row32 col0" >120,551</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Chúng ta có thể chọn Top 10 thể loại ứng dụng có lượt cài đặt trung bình cao nhất để đề xuất các nhà phát triển. Tuy nhiên hãy phân tích sâu hơn từng thể loại để tìm ra đâu là thể loại cần được ưu tiên.
#
# ### Phân tích các ứng dụng bên trong mỗi thể loại Android
#
# #### Phần 1: Tìm các giá trị distinct trong cột Installs
#
# Giá trị trong cột **Installs** của ứng dụng Android được liệt kê ở dạng tóm tắt (10,000+ | 100,000+ | 1,000,000+ | ...) nên chúng ta cần tìm xem có bao nhiêu giá trị distinct trong cột này. Sau đó chúng ta sẽ nhóm các ứng dụng lại dựa theo các giá trị distinct để phân tích.

# %%
# Distinct Value Installs
pd.DataFrame(df_android_english_free.Installs.drop_duplicates().sort_values(ascending=False).reset_index(drop=True)).style.format("{:,}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_19d51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19d51_level0_col0" class="col_heading level0 col0" >Installs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19d51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19d51_row0_col0" class="data row0 col0" >1,000,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19d51_row1_col0" class="data row1 col0" >500,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19d51_row2_col0" class="data row2 col0" >100,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19d51_row3_col0" class="data row3 col0" >50,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19d51_row4_col0" class="data row4 col0" >10,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19d51_row5_col0" class="data row5 col0" >5,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_19d51_row6_col0" class="data row6 col0" >1,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_19d51_row7_col0" class="data row7 col0" >500,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_19d51_row8_col0" class="data row8 col0" >100,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_19d51_row9_col0" class="data row9 col0" >50,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_19d51_row10_col0" class="data row10 col0" >10,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_19d51_row11_col0" class="data row11 col0" >5,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_19d51_row12_col0" class="data row12 col0" >1,000</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_19d51_row13_col0" class="data row13 col0" >500</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_19d51_row14_col0" class="data row14 col0" >100</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_19d51_row15_col0" class="data row15 col0" >50</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_19d51_row16_col0" class="data row16 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_19d51_row17_col0" class="data row17 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_19d51_row18_col0" class="data row18 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_19d51_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_19d51_row19_col0" class="data row19 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Chúng ta sẽ chọn ra 2 phân khúc để thuận tiện cho việc phân tích:
# - **Phân khúc 1 - có lượt cài đặt cao nhất:** Installs => 100,000,000.
# - **Phân khúc 2 - có lượt cài đặt trung bình (ở giữa):** 5,000,000 <= Installs <= 50,000,000.
#
# #### Phần 2: Phân tích các ứng dụng bên trong mỗi thể loại
#
# Các tiêu chí để chúng ta quyết định thể loại ứng dụng nào được ưu tiên phát triển.
#
# 1. Có nhiều hay ít ứng dụng trong phân khúc 1? Nếu quá nhiều ứng dụng thì thể loại đó không được ưu tiên vì nó quá cạnh tranh.
# 2. Có nhiều hay ít người khổng lồ đang chiếm lĩnh thị trường? Nếu quá nhiều người khổng lồ thì thể loại đó cũng không được ưu tiên.
#
# Thể loại lý tưởng sẽ có có ít ứng dụng ở phân khúc 1 và không có nhiều người khổng lồ đang chiếm lĩnh thị trường.

# %%
# Show android apps by category
def show_android_apps(category):
    df = df_android_english_free
    cond_high = (df.Installs >= 100000000) & (df.Category == category)
    cond_middle = (df.Installs >= 5000000) & (df.Installs <= 50000000) & (df.Category == category)
    high = df[cond_high][['Installs','App']].sort_values(by='Installs', ascending=False).reset_index(drop=True)
    middle = df[cond_middle][['Installs','App']].sort_values(by='Installs', ascending=False).reset_index(drop=True)
    
    print(f'{"-"*88}\nAndroid | {category} - high installs: {high.shape[0]}\n{"-"*88}')
    for row in high.values:
        print(f'{row[0]:,} : {row[1]}')
    print(f'{"-"*88}\nAndroid | {category} - middle installs: {middle.shape[0]}\n{"-"*88}')
    for row in middle.values:
        print(f'{row[0]:,} : {row[1]}')
    print('\n')

# %%
# Check with COMMUNICATION category
show_android_apps('COMMUNICATION')
# Out:
# ----------------------------------------------------------------------------------------------------
# Android | COMMUNICATION - high installs: 27
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : WhatsApp Messenger
# 1,000,000,000 : Skype - free IM & video calls
# 1,000,000,000 : Gmail
# 1,000,000,000 : Google Chrome: Fast & Secure
# 1,000,000,000 : Messenger – Text and Video Chat for Free
# 1,000,000,000 : Hangouts
# 500,000,000 : imo free video calls and chat
# 500,000,000 : Viber Messenger
# 500,000,000 : LINE: Free Calls & Messages
# 500,000,000 : UC Browser - Fast Download Private & Secure
# 500,000,000 : Google Duo - High Quality Video Calls
# 100,000,000 : Truecaller: Caller ID, SMS spam blocking & Dialer
# 100,000,000 : WeChat
# 100,000,000 : Yahoo Mail – Stay Organized
# 100,000,000 : UC Browser Mini -Tiny Fast Private & Secure
# 100,000,000 : imo beta free calls and text
# 100,000,000 : Who
# 100,000,000 : Android Messages
# 100,000,000 : Telegram
# 100,000,000 : Opera Mini - fast web browser
# 100,000,000 : BBM - Free Calls & Messages
# 100,000,000 : Messenger Lite: Free Calls & Messages
# 100,000,000 : Kik
# 100,000,000 : KakaoTalk: Free Calls & Text
# 100,000,000 : GO SMS Pro - Messenger, Free Themes, Emoji
# 100,000,000 : Firefox Browser fast & private
# 100,000,000 : Opera Browser: Fast and Secure
# ----------------------------------------------------------------------------------------------------
# Android | COMMUNICATION - middle installs: 72
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : free video calls and chat
# 50,000,000 : Azar
# 50,000,000 : Contacts
# 50,000,000 : Zalo – Video Call
# 50,000,000 : Mail.Ru - Email App
# 50,000,000 : CM Browser - Ad Blocker , Fast Download , Privacy
# 50,000,000 : Dolphin Browser - Fast, Private & Adblock🐬
# 10,000,000 : Hiya - Caller ID & Block
# 10,000,000 : Omlet Chat
# 10,000,000 : Portable Wi-Fi hotspot
# 10,000,000 : Orfox: Tor Browser for Android
# 10,000,000 : Opera Mini browser beta
# 10,000,000 : MegaFon Dashboard
# 10,000,000 : Mr. Number-Block calls & spam
# 10,000,000 : Messenger for SMS
# 10,000,000 : Puffin Web Browser
# 10,000,000 : ICQ — Video Calls & Chat Messenger
# 10,000,000 : AT&T Visual Voicemail
# 10,000,000 : Psiphon Pro - The Internet Freedom VPN
# 10,000,000 : Talkray - Free Calls & Texts
# 10,000,000 : Talkatone: Free Texts, Calls & Phone Number
# 10,000,000 : GroupMe
# 10,000,000 : Text SMS
# 10,000,000 : TouchPal Keyboard - Fun Emoji & Android Keyboard
# 10,000,000 : Voxer Walkie Talkie Messenger
# 10,000,000 : WEB.DE Mail
# 10,000,000 : WhatsApp Business
# 10,000,000 : WhatsCall Free Global Phone Call App & Cheap Calls
# 10,000,000 : Whoscall - Caller ID & Block
# 10,000,000 : Xperia Link™
# 10,000,000 : ZenUI Dialer & Contacts
# 10,000,000 : chomp SMS
# 10,000,000 : Hangouts Dialer - Call Phones
# 10,000,000 : myMail – Email for Hotmail, Gmail and Outlook Mail
# 10,000,000 : Google Voice
# 10,000,000 : Free Adblocker Browser - Adblock & Popup Blocker
# 10,000,000 : Calls Blacklist - Call Blocker
# 10,000,000 : Contacts+
# 10,000,000 : Google Allo
# 10,000,000 : Cricket Visual Voicemail
# 10,000,000 : DU Browser—Browse fast & fun
# 10,000,000 : Discord - Chat for Gamers
# 10,000,000 : ExDialer - Dialer & Contacts
# 10,000,000 : CallApp: Caller ID, Blocker & Phone Call Recorder
# 10,000,000 : Browser 4G
# 10,000,000 : Free WiFi Connect
# 10,000,000 : GMX Mail
# 10,000,000 : Adblock Browser for Android
# 10,000,000 : GO Notifier
# 10,000,000 : Glide - Video Chat Messenger
# 5,000,000 : Your Freedom VPN Client
# 5,000,000 : Caller ID & Call Block - DU Caller
# 5,000,000 : CM Transfer - Share any files with friends nearby
# 5,000,000 : Brave Browser: Fast AdBlocker
# 5,000,000 : Call Control - Call Blocker
# 5,000,000 : Bluetooth Auto Connect
# 5,000,000 : Call Free – Free Call
# 5,000,000 : Web Browser & Explorer
# 5,000,000 : CIA - Caller ID & Call Blocker
# 5,000,000 : Skype Lite - Free Video Call & Chat
# 5,000,000 : Calls & Text by Mo+
# 5,000,000 : Chrome Dev
# 5,000,000 : Sync.ME – Caller ID & Block
# 5,000,000 : Daum Mail - Next Mail
# 5,000,000 : Ear Agent: Super Hearing
# 5,000,000 : My Vodacom SA
# 5,000,000 : My Tele2
# 5,000,000 : Microsoft Edge
# 5,000,000 : Full Screen Caller ID
# 5,000,000 : K-9 Mail
# 5,000,000 : JusTalk - Free Video Calls and Fun Video Chat
# 5,000,000 : AT&T Call Protect

# %% [markdown]
# **COMMUNICATION:** Chúng ta thấy có quá nhiều ứng dụng trong phân khúc 1, và nhiều khổng lồ trong thể loại này như WhatsApp, Skype, Messenger, Hangouts,... Vì vậy chúng ta nên bỏ qua thể loại này.
#
# Chúng ta sẽ phân tích tương tự với một các thể loại còn lại

# %%
# Show all apps by categories
show_android_apps('VIDEO_PLAYERS')
show_android_apps('SOCIAL')
show_android_apps('PHOTOGRAPHY')
show_android_apps('PRODUCTIVITY')
show_android_apps('GAME')
show_android_apps('TRAVEL_AND_LOCAL')
show_android_apps('ENTERTAINMENT')
show_android_apps('TOOLS')
show_android_apps('NEWS_AND_MAGAZINES')
show_android_apps('BOOKS_AND_REFERENCE')
# Out:
# ----------------------------------------------------------------------------------------------------
# Android | VIDEO_PLAYERS - high installs: 9
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Google Play Movies & TV
# 1,000,000,000 : YouTube
# 500,000,000 : MX Player
# 100,000,000 : Dubsmash
# 100,000,000 : Motorola FM Radio
# 100,000,000 : Motorola Gallery
# 100,000,000 : VLC for Android
# 100,000,000 : VideoShow-Video Editor, Video Maker, Beauty Camera
# 100,000,000 : VivaVideo - Video Editor & Photo Movie
# ----------------------------------------------------------------------------------------------------
# Android | VIDEO_PLAYERS - middle installs: 43
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : MiniMovie - Free Video and Slideshow Editor
# 50,000,000 : Ringdroid
# 50,000,000 : LIKE – Magic Video Maker & Community
# 50,000,000 : Vote for
# 50,000,000 : Vigo Video
# 50,000,000 : KineMaster – Pro Video Editor
# 50,000,000 : DU Recorder – Screen Recorder, Video Editor, Live
# 50,000,000 : VMate
# 50,000,000 : Samsung Video Library
# 50,000,000 : HD Video Downloader : 2018 Best video mate
# 10,000,000 : Naruto Shippuden - Watch Free!
# 10,000,000 : Omlet Arcade - Stream, Meet, Play
# 10,000,000 : PowerDirector Video Editor App: 4K, Slow Mo & More
# 10,000,000 : Quik – Free Video Editor for photos, clips, music
# 10,000,000 : Ustream
# 10,000,000 : Mobizen Screen Recorder for SAMSUNG
# 10,000,000 : Video Downloader
# 10,000,000 : Video Downloader - for Instagram Repost App
# 10,000,000 : Video Player All Format
# 10,000,000 : YouTube Studio
# 10,000,000 : iMediaShare – Photos & Music
# 10,000,000 : Music - Mp3 Player
# 10,000,000 : AZ Screen Recorder - No Root
# 10,000,000 : Cartoon Network App
# 10,000,000 : Code
# 10,000,000 : AfreecaTV
# 10,000,000 : All Video Downloader
# 10,000,000 : BSPlayer FREE
# 10,000,000 : BitTorrent®- Torrent Downloads
# 10,000,000 : Magisto Video Editor & Maker
# 10,000,000 : video player for android
# 10,000,000 : FilmoraGo - Free Video Editor
# 10,000,000 : FrostWire: Torrent Downloader & Music Player
# 10,000,000 : HTC Gallery
# 10,000,000 : HTC Service － DLNA
# 10,000,000 : Inst Download - Video & Photo
# 5,000,000 : Droid Zap by Motorola
# 5,000,000 : Video Editor
# 5,000,000 : HTC Service—Video Player
# 5,000,000 : WiFi Baby Monitor - NannyCam
# 5,000,000 : YouCut - Video Editor & Video Maker, No Watermark
# 5,000,000 : Adobe Premiere Clip
# 5,000,000 : ActionDirector Video Editor - Edit Videos Fast
#
#
# ----------------------------------------------------------------------------------------------------
# Android | SOCIAL - high installs: 13
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Facebook
# 1,000,000,000 : Google+
# 1,000,000,000 : Instagram
# 500,000,000 : Facebook Lite
# 500,000,000 : Snapchat
# 100,000,000 : BIGO LIVE - Live Stream
# 100,000,000 : Badoo - Free Chat & Dating App
# 100,000,000 : LinkedIn
# 100,000,000 : Pinterest
# 100,000,000 : Tango - Live Video Broadcast
# 100,000,000 : Tik Tok - including musical.ly
# 100,000,000 : Tumblr
# 100,000,000 : VK
# ----------------------------------------------------------------------------------------------------
# Android | SOCIAL - middle installs: 54
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : POF Free Dating App
# 50,000,000 : ooVoo Video Calls, Messaging & Stories
# 50,000,000 : MeetMe: Chat & Meet New People
# 50,000,000 : Zello PTT Walkie Talkie
# 50,000,000 : SKOUT - Meet, Chat, Go Live
# 10,000,000 : Tagged - Meet, Chat & Dating
# 10,000,000 : Mico- Stranger Chat Random video Chat, Live, Meet
# 10,000,000 : Path
# 10,000,000 : Periscope - Live Video
# 10,000,000 : Phone Tracker : Family Locator
# 10,000,000 : Quora
# 10,000,000 : SayHi Chat, Meet New People
# 10,000,000 : Tapatalk - 100,000+ Forums
# 10,000,000 : Messenger
# 10,000,000 : Text Me: Text Free, Call Free, Second Phone Number
# 10,000,000 : Text free - Free Text + Call
# 10,000,000 : TextNow - free text + calls
# 10,000,000 : Waplog - Free Chat, Dating App, Meet Singles
# 10,000,000 : We Heart It
# 10,000,000 : YouNow: Live Stream Video Chat
# 10,000,000 : magicApp Calling & Messaging
# 10,000,000 : Messenger Messenger
# 10,000,000 : Amino: Communities and Chats
# 10,000,000 : Messages, Text and Video Chat for Messenger
# 10,000,000 : Kate Mobile for VK
# 10,000,000 : Dating App, Flirt & Chat : W-Match
# 10,000,000 : Find My Friends
# 10,000,000 : Free phone calls, free texting SMS on free number
# 10,000,000 : Grindr - Gay chat
# 10,000,000 : HTC Social Plugin - Facebook
# 10,000,000 : Jaumo Dating, Flirt & Live Video
# 10,000,000 : textPlus: Free Text & Calls
# 10,000,000 : LOVOO
# 10,000,000 : Legend - Animate Text in Video
# 10,000,000 : LiveMe - Video chat, new friends, and make money
# 5,000,000 : FunForMobile Ringtones & Chat
# 5,000,000 : Meet – Talk to Strangers Using Random Video Chat
# 5,000,000 : Fame Boom for Real Followers, Likes
# 5,000,000 : Nextdoor - Local neighborhood news & classifieds
# 5,000,000 : Blogger
# 5,000,000 : Who Viewed My Facebook Profile - Stalkers Visitors
# 5,000,000 : Whisper
# 5,000,000 : Web Browser & Fast Explorer
# 5,000,000 : Frim: get new friends on local chat rooms
# 5,000,000 : VidStatus app - Status Videos & Status Downloader
# 5,000,000 : SPARK - Live random video chat & meet new people
# 5,000,000 : Timehop
# 5,000,000 : HOLLA Live: Meet New People via Random Video Chat
# 5,000,000 : Meetup
# 5,000,000 : Telegram X
# 5,000,000 : Hide Something - Photo, Video
# 5,000,000 : Hornet - Gay Social Network
# 5,000,000 : Instachat 😜
# 5,000,000 : Text Free: WiFi Calling App
#
#
# ----------------------------------------------------------------------------------------------------
# Android | PHOTOGRAPHY - high installs: 19
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Google Photos
# 100,000,000 : AR effect
# 100,000,000 : Photo Editor Pro
# 100,000,000 : YouCam Perfect - Selfie Photo Editor
# 100,000,000 : YouCam Makeup - Magic Selfie Makeovers
# 100,000,000 : Sweet Selfie - selfie camera, beauty cam, photo edit
# 100,000,000 : S Photo Editor - Collage Maker , Photo Collage
# 100,000,000 : Retrica
# 100,000,000 : PicsArt Photo Studio: Collage Maker & Pic Editor
# 100,000,000 : PhotoGrid: Video & Pic Collage Maker, Photo Editor
# 100,000,000 : Photo Editor Collage Maker Pro
# 100,000,000 : B612 - Beauty & Filter Camera
# 100,000,000 : Photo Collage Editor
# 100,000,000 : LINE Camera - Photo editor
# 100,000,000 : Cymera Camera- Photo Editor, Filter,Collage,Layout
# 100,000,000 : Candy Camera - selfie, beauty camera, photo editor
# 100,000,000 : Camera360: Selfie Photo Editor with Funny Sticker
# 100,000,000 : BeautyPlus - Easy Photo Editor & Selfie Camera
# 100,000,000 : Z Camera - Photo Editor, Beauty Selfie, Collage
# ----------------------------------------------------------------------------------------------------
# Android | PHOTOGRAPHY - middle installs: 105
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : InstaBeauty -Makeup Selfie Cam
# 50,000,000 : Boomerang from Instagram
# 50,000,000 : Keepsafe Photo Vault: Hide Private Photos & Videos
# 50,000,000 : InstaSize Photo Filters & Collage Editor
# 50,000,000 : MomentCam Cartoons & Stickers
# 50,000,000 : Motorola Camera
# 50,000,000 : Snapseed
# 50,000,000 : Square InPic - Photo Editor & Collage Maker
# 50,000,000 : Photo Editor Selfie Camera Filter & Mirror Image
# 50,000,000 : Photo Editor by Aviary
# 50,000,000 : Selfie Camera - Photo Editor & Filter & Sticker
# 50,000,000 : Photo Effects Pro
# 50,000,000 : Photo Lab Picture Editor: face effects, art frames
# 50,000,000 : SNOW - AR Camera
# 50,000,000 : MakeupPlus - Your Own Virtual Makeup Artist
# 50,000,000 : VSCO
# 50,000,000 : Video Editor Music,Cut,No Crop
# 50,000,000 : Pic Collage - Photo Editor
# 50,000,000 : Adobe Photoshop Express:Photo Editor Collage Maker
# 50,000,000 : PhotoWonder: Pro Beauty Photo Editor Collage Maker
# 50,000,000 : Pixlr – Free Photo Editor
# 50,000,000 : ASUS Gallery
# 10,000,000 : Retro Camera
# 10,000,000 : A+ Gallery - Photos & Videos
# 10,000,000 : Mirror Photo:Editor Collage (HD)
# 10,000,000 : PIP Selfie Camera Photo Editor
# 10,000,000 : Scoompa Video - Slideshow Maker and Video Editor
# 10,000,000 : Meitu – Beauty Cam, Easy Photo Editor
# 10,000,000 : PixelLab - Text on pictures
# 10,000,000 : My Photo Keyboard
# 10,000,000 : No Crop & Square for Instagram
# 10,000,000 : Open Camera
# 10,000,000 : PhotoFunia
# 10,000,000 : Phonto - Text on Photos
# 10,000,000 : PhotoLayers〜Superimpose,Eraser
# 10,000,000 : Photo Collage - Layout Editor
# 10,000,000 : Photo Collage Maker
# 10,000,000 : Photo Editor
# 10,000,000 : RetroSelfie - Selfie Editor
# 10,000,000 : Photo Editor by BeFunky
# 10,000,000 : Photo Frame
# 10,000,000 : Photo Frames
# 10,000,000 : PhotoScan by Google Photos
# 10,000,000 : Photo Mixer
# 10,000,000 : Photo Studio
# 10,000,000 : PhotoDirector Photo Editor App
# 10,000,000 : Photo Collage - InstaMag
# 10,000,000 : Wondershare PowerCam
# 10,000,000 : Love Collage - Photo Editor
# 10,000,000 : Bokeh (Background defocus)
# 10,000,000 : Cameringo Lite. Filters Camera
# 10,000,000 : Camera360 Lite - Selfie Camera
# 10,000,000 : Camera for Android
# 10,000,000 : Sweet Camera - Selfie Filters, Beauty Camera
# 10,000,000 : Camera MX - Free Photo & Video Camera
# 10,000,000 : Camera FV-5 Lite
# 10,000,000 : Sweet Snap - live filter, Selfie photo edit
# 10,000,000 : LightX Photo Editor & Photo Effects
# 10,000,000 : Blur Image Background
# 10,000,000 : Bestie - Camera360 Selfie
# 10,000,000 : Beauty Makeup Snappy Collage Photo Editor - Lidow
# 10,000,000 : Background Eraser
# 10,000,000 : AfterFocus
# 10,000,000 : ASUS PixelMaster Camera
# 10,000,000 : Candy selfie - photo editor, live filter camera
# 10,000,000 : Pixlr-o-matic
# 10,000,000 : Color Touch Effects
# 10,000,000 : Font Studio- Photo Texts Image
# 10,000,000 : QuickPic - Photo Gallery with Google Drive Support
# 10,000,000 : HD Camera for Android
# 10,000,000 : HD Camera Ultra
# 10,000,000 : GoPro (formerly Capture)
# 10,000,000 : Fotor Photo Editor - Photo Collage & Photo Effects
# 10,000,000 : Free Slideshow Maker & Video Editor
# 10,000,000 : Flickr
# 10,000,000 : Facejjang
# 10,000,000 : FaceApp
# 10,000,000 : Face Filter, Selfie Editor - Sweet Camera
# 10,000,000 : EyeEm - Camera & Photo Filter
# 5,000,000 : Sweet Camera
# 5,000,000 : Story Saver for Instagram
# 5,000,000 : Silent Camera [High Quality]
# 5,000,000 : Shutterfly: Free Prints, Photo Books, Cards, Gifts
# 5,000,000 : Visage Lab – face retouch
# 5,000,000 : SuperPhoto - Effects & Filters
# 5,000,000 : A Better Camera
# 5,000,000 : Pretty Makeup, Beauty Photo Editor & Snappy Camera
# 5,000,000 : Ghost In Photo
# 5,000,000 : Adobe Illustrator Draw
# 5,000,000 : Adobe Photoshop Fix
# 5,000,000 : Blur Image - DSLR focus effect
# 5,000,000 : Blur Image Background Editor (Blur Photo Editor)
# 5,000,000 : Camera ZOOM FX - FREE
# 5,000,000 : Change photo background
# 5,000,000 : Collage&Add Stickers papelook
# 5,000,000 : HD Camera
# 5,000,000 : Pixgram- video photo slideshow
# 5,000,000 : HD Camera - Best Cam with filters & panorama
# 5,000,000 : High-Speed Camera (GIF,Burst)
# 5,000,000 : Huji Cam
# 5,000,000 : MIX by Camera360
# 5,000,000 : Muzy - Share photos & collages
# 5,000,000 : Photo Editor-
# 5,000,000 : Picture Grid Builder
# 5,000,000 : Moto Photo Editor
#
#
# ----------------------------------------------------------------------------------------------------
# Android | PRODUCTIVITY - high installs: 22
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Google Drive
# 500,000,000 : Cloud Print
# 500,000,000 : Dropbox
# 500,000,000 : Microsoft Word
# 500,000,000 : Google Calendar
# 100,000,000 : Adobe Acrobat Reader
# 100,000,000 : Microsoft Excel
# 100,000,000 : SwiftKey Keyboard
# 100,000,000 : Samsung Notes
# 100,000,000 : Microsoft PowerPoint
# 100,000,000 : Microsoft Outlook
# 100,000,000 : Microsoft OneNote
# 100,000,000 : Microsoft OneDrive
# 100,000,000 : Google Sheets
# 100,000,000 : Google Slides
# 100,000,000 : CamScanner - Phone PDF Creator
# 100,000,000 : Google Keep
# 100,000,000 : Google Docs
# 100,000,000 : Evernote – Organizer, Planner for Notes & Memos
# 100,000,000 : ES File Explorer File Manager
# 100,000,000 : ColorNote Notepad Notes
# 100,000,000 : WPS Office - Word, Docs, PDF, Note, Slide & Sheet
# ----------------------------------------------------------------------------------------------------
# Android | PRODUCTIVITY - middle installs: 69
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : myAT&T
# 50,000,000 : QR Droid
# 50,000,000 : MEGA
# 50,000,000 : File Browser by Astro (File Manager)
# 50,000,000 : Do It Later: Tasks & To-Dos
# 50,000,000 : Mobizen Screen Recorder - Record, Capture, Edit
# 50,000,000 : My Airtel-Online Recharge, Pay Bill, Wallet, UPI
# 50,000,000 : Calculator - unit converter
# 50,000,000 : Advanced Task Killer
# 50,000,000 : Verizon Cloud
# 50,000,000 : Alarm Clock: Stopwatch & Timer
# 10,000,000 : ASUS Calling Screen
# 10,000,000 : Keeper: Free Password Manager & Secure Vault
# 10,000,000 : LOCX Applock Lock Apps & Photo
# 10,000,000 : iTranslate Translator & Dictionary
# 10,000,000 : aCalendar - Android Phone
# 10,000,000 : Metro name iD
# 10,000,000 : Mobile Security & Antivirus
# 10,000,000 : Mobile Security: Antivirus, Web Scan & App Lock
# 10,000,000 : Wunderlist: To-Do List & Tasks
# 10,000,000 : U+Box
# 10,000,000 : Todoist: To-do lists for task management & errands
# 10,000,000 : MyVodafone (India) - Online Recharge & Pay Bills
# 10,000,000 : NQ Mobile Security & Antivirus
# 10,000,000 : Notepad
# 10,000,000 : HTC Mail
# 10,000,000 : Notepad & To do list
# 10,000,000 : Polaris Office - Word, Docs, Sheets, Slide, PDF
# 10,000,000 : QR Scanner & Barcode Scanner 2018
# 10,000,000 : S Note
# 10,000,000 : Jorte Calendar & Organizer
# 10,000,000 : APUS Booster - Space Cleaner & Booster
# 10,000,000 : HTC File Manager
# 10,000,000 : Chrome Beta
# 10,000,000 : ASUS Quick Memo
# 10,000,000 : ASUS SuperNote
# 10,000,000 : AT&T Mobile Transfer
# 10,000,000 : AVG Cleaner – Speed, Battery & Memory Booster
# 10,000,000 : All-In-One Toolbox: Cleaner, Booster, App Manager
# 10,000,000 : AndroZip™ FREE File Manager
# 10,000,000 : Any.do: To-do list, Calendar, Reminders & Planner
# 10,000,000 : AutoCAD - DWG Viewer & Editor
# 10,000,000 : HTC Calendar
# 10,000,000 : CM FILE MANAGER HD
# 10,000,000 : Google PDF Viewer
# 10,000,000 : Google Assistant
# 10,000,000 : Easy Voice Recorder
# 10,000,000 : Fake Call - Fake Caller ID
# 5,000,000 : Content Transfer
# 5,000,000 : To Do List
# 5,000,000 : lifebox
# 5,000,000 : Yandex.Disk
# 5,000,000 : Ginger Keyboard - Emoji, GIFs, Themes & Games
# 5,000,000 : G Cloud Backup
# 5,000,000 : Ultimate Notepad
# 5,000,000 : MediaFire
# 5,000,000 : Trello
# 5,000,000 : The Maner
# 5,000,000 : My Claro Peru
# 5,000,000 : Microsoft Translator
# 5,000,000 : Archos File Manager
# 5,000,000 : Business Calendar 2
# 5,000,000 : PDF Viewer & Book Reader
# 5,000,000 : EBookDroid - PDF & DJVU Reader
# 5,000,000 : Calendar Widget Month + Agenda
# 5,000,000 : Note Everything
# 5,000,000 : DigiCal Calendar Agenda
# 5,000,000 : Clean My Android
# 5,000,000 : Keep My Notes - Notepad & Memo
#
#
# ----------------------------------------------------------------------------------------------------
# Android | GAME - high installs: 59
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Subway Surfers
# 500,000,000 : My Talking Tom
# 500,000,000 : Temple Run 2
# 500,000,000 : Candy Crush Saga
# 500,000,000 : Pou
# 100,000,000 : 8 Ball Pool
# 100,000,000 : Shadow Fight 2
# 100,000,000 : Mobile Legends: Bang Bang
# 100,000,000 : Modern Combat 5: eSports FPS
# 100,000,000 : My Talking Angela
# 100,000,000 : PAC-MAN
# 100,000,000 : Piano Tiles 2™
# 100,000,000 : Plants vs. Zombies FREE
# 100,000,000 : Pokémon GO
# 100,000,000 : Roll the Ball® - slide puzzle
# 100,000,000 : Score! Hero
# 100,000,000 : Smash Hit
# 100,000,000 : Skater Boy
# 100,000,000 : Jetpack Joyride
# 100,000,000 : Sniper 3D Gun Shooter: Free Shooting Games - FPS
# 100,000,000 : Sonic Dash
# 100,000,000 : Super Mario Run
# 100,000,000 : Talking Tom Gold Run
# 100,000,000 : Temple Run
# 100,000,000 : Traffic Racer
# 100,000,000 : Trivia Crack
# 100,000,000 : Vector
# 100,000,000 : Yes day
# 100,000,000 : Zombie Tsunami
# 100,000,000 : Lep's World 2 🍀🍀
# 100,000,000 : Hungry Shark Evolution
# 100,000,000 : Agar.io
# 100,000,000 : Hill Climb Racing 2
# 100,000,000 : Angry Birds 2
# 100,000,000 : Angry Birds Classic
# 100,000,000 : Angry Birds Rio
# 100,000,000 : Angry Birds Star Wars
# 100,000,000 : Ant Smasher by Best Cool & Fun Games
# 100,000,000 : Asphalt 8: Airborne
# 100,000,000 : Banana Kong
# 100,000,000 : Bike Race Free - Top Motorcycle Racing Games
# 100,000,000 : Bus Rush: Subway Edition
# 100,000,000 : Candy Crush Soda Saga
# 100,000,000 : Clash Royale
# 100,000,000 : Clash of Clans
# 100,000,000 : Cooking Fever
# 100,000,000 : Crossy Road
# 100,000,000 : Cut the Rope FULL FREE
# 100,000,000 : Dr. Driving
# 100,000,000 : Dream League Soccer 2018
# 100,000,000 : Extreme Car Driving Simulator
# 100,000,000 : Flow Free
# 100,000,000 : Fruit Ninja®
# 100,000,000 : Garena Free Fire
# 100,000,000 : Geometry Dash Lite
# 100,000,000 : Glow Hockey
# 100,000,000 : Helix Jump
# 100,000,000 : Hill Climb Racing
# 100,000,000 : slither.io
# ----------------------------------------------------------------------------------------------------
# Android | GAME - middle installs: 322
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : DEER HUNTER CLASSIC
# 50,000,000 : Rolling Sky
# 50,000,000 : Draw Something Classic
# 50,000,000 : Dr. Parking 4
# 50,000,000 : Racing Moto
# 50,000,000 : Doodle Jump
# 50,000,000 : Racing in Car 2
# 50,000,000 : Red Ball 4
# 50,000,000 : DEAD TARGET: FPS Zombie Apocalypse Survival Games
# 50,000,000 : Pixel Gun 3D: Survival shooter & Battle Royale
# 50,000,000 : Shoot Hunter-Gun Killer
# 50,000,000 : Snake VS Block
# 50,000,000 : Chess Free
# 50,000,000 : Candy Crush Jelly Saga
# 50,000,000 : Summoners War
# 50,000,000 : Swamp Attack
# 50,000,000 : Earn to Die 2
# 50,000,000 : Piano Free - Keyboard with Magic Tiles Music Games
# 50,000,000 : Bubble Witch 3 Saga
# 50,000,000 : MARVEL Contest of Champions
# 50,000,000 : Kick the Buddy
# 50,000,000 : Lep's World 3 🍀🍀🍀
# 50,000,000 : Lep's World 🍀
# 50,000,000 : Lords Mobile: Battle of the Empires - Strategy RPG
# 50,000,000 : Love Balls
# 50,000,000 : Granny
# 50,000,000 : Magic Tiles 3
# 50,000,000 : Perfect Piano
# 50,000,000 : Geometry Dash Meltdown
# 50,000,000 : Gardenscapes
# 50,000,000 : Gangstar Vegas - mafia game
# 50,000,000 : GUNSHIP BATTLE: Helicopter 3D
# 50,000,000 : Need for Speed™ No Limits
# 50,000,000 : PUBG MOBILE
# 50,000,000 : CATS: Crash Arena Turbo Stars
# 50,000,000 : Hungry Shark World
# 50,000,000 : Angry Birds Friends
# 50,000,000 : Beach Buggy Blitz
# 50,000,000 : Zynga Poker – Texas Holdem
# 50,000,000 : Angry Birds Go!
# 50,000,000 : Anger of stick 5 : zombie
# 50,000,000 : Block Craft 3D: Building Simulator Games For Free
# 50,000,000 : UNO ™ & Friends
# 50,000,000 : ► MultiCraft ― Free Miner! 👍
# 50,000,000 : Bike Racing 3D
# 50,000,000 : War Robots
# 50,000,000 : Toy Truck Rally 3D
# 50,000,000 : Bowmasters
# 50,000,000 : Toy Blast
# 50,000,000 : Words With Friends Classic
# 50,000,000 : Word Search
# 50,000,000 : BMX Boy
# 10,000,000 : Miraculous Ladybug & Cat Noir - The Official Game
# 10,000,000 : Modern Strike Online
# 10,000,000 : Moto Fighter 3D
# 10,000,000 : Moto Rider
# 10,000,000 : Motorbike Driving Simulator 3D
# 10,000,000 : My Boy! Free - GBA Emulator
# 10,000,000 : Texas HoldEm Poker Deluxe
# 10,000,000 : Navy Gunner Shoot War 3D
# 10,000,000 : NinJump
# 10,000,000 : Nyan Cat: Lost In Space
# 10,000,000 : Miami Crime Vice Town
# 10,000,000 : Wordscapes
# 10,000,000 : Paint Hit
# 10,000,000 : Partymasters - Fun Idle Game
# 10,000,000 : Words With Friends – Play Free
# 10,000,000 : Pineapple Pen
# 10,000,000 : Pixel Art: Color by Number Game
# 10,000,000 : Miami crime simulator
# 10,000,000 : Zombie Catchers
# 10,000,000 : World Series of Poker – WSOP Free Texas Holdem
# 10,000,000 : Metal Soldiers 2
# 10,000,000 : Injustice: Gods Among Us
# 10,000,000 : Iron Blade
# 10,000,000 : Jewels Legend - Match 3 Puzzle
# 10,000,000 : Jungle Monkey Run
# 10,000,000 : Just Dance Now
# 10,000,000 : KIM KARDASHIAN: HOLLYWOOD
# 10,000,000 : Kill Shot Bravo: Sniper FPS
# 10,000,000 : Knife Hit
# 10,000,000 : Kung Fu Do Fighting
# 10,000,000 : Last Day on Earth: Survival
# 10,000,000 : nds4droid
# 10,000,000 : Live Hold’em Pro Poker - Free Casino Games
# 10,000,000 : iGun Pro -The Original Gun App
# 10,000,000 : MARVEL Avengers Academy
# 10,000,000 : diep.io
# 10,000,000 : MORTAL KOMBAT X
# 10,000,000 : Mafia City
# 10,000,000 : Major Mayhem
# 10,000,000 : Zombie Hunter: Post Apocalypse Survival Games
# 10,000,000 : Marble - Temple Quest
# 10,000,000 : Zombie Frontier
# 10,000,000 : Marble Woka Woka 2018 - Bubble Shooter Match 3
# 10,000,000 : Power Pop Bubbles
# 10,000,000 : Police Car Driver
# 10,000,000 : Quiz: Logo game
# 10,000,000 : Power Rangers Dino Charge
# 10,000,000 : Sniper Killer Shooter
# 10,000,000 : Solitaire TriPeaks
# 10,000,000 : Solitaire!
# 10,000,000 : Sonic the Hedgehog™ Classic
# 10,000,000 : Soul Knight
# 10,000,000 : Space Shooter : Galaxy Attack
# 10,000,000 : Special Forces Group 2
# 10,000,000 : Squadron - Bullet Hell Shooter
# 10,000,000 : Stack Jump
# 10,000,000 : The Walking Dead: Road to Survival
# 10,000,000 : Standoff 2
# 10,000,000 : Stick War: Legacy
# 10,000,000 : StirFry Stunts - We Bare Bears
# 10,000,000 : Strange Hero: Future Battle
# 10,000,000 : The Sims™ FreePlay
# 10,000,000 : Street Skater 3D
# 10,000,000 : Stupid Zombies
# 10,000,000 : The Maze Runner
# 10,000,000 : Super Jabber Jump
# 10,000,000 : Survival: Prison Escape
# 10,000,000 : Texas Holdem Poker
# 10,000,000 : Sweet Fruit Candy
# 10,000,000 : TRANSFORMERS: Forged to Fight
# 10,000,000 : Texas Holdem & Omaha Poker: Pokerist
# 10,000,000 : Solitaire
# 10,000,000 : Toon Blast
# 10,000,000 : Power Rangers: Legacy Wars
# 10,000,000 : Slot Machines by IGG
# 10,000,000 : Word Link
# 10,000,000 : Tank Stars
# 10,000,000 : RULES OF SURVIVAL
# 10,000,000 : Race the Traffic Moto
# 10,000,000 : Truck Driver Cargo
# 10,000,000 : Real City Car Driver
# 10,000,000 : Real Gangster Crime
# 10,000,000 : Train Racing Games 3D 2 Player
# 10,000,000 : Red Hands – 2-Player Games
# 10,000,000 : Rento - Dice Board Game Online
# 10,000,000 : Rider
# 10,000,000 : Robbery Bob
# 10,000,000 : Rolly Vortex
# 10,000,000 : Rope Hero: Vice Town
# 10,000,000 : Rope'n'Fly 3 - Dusk Till Dawn
# 10,000,000 : Ingress
# 10,000,000 : Rope'n'Fly 4
# 10,000,000 : Run Sausage Run!
# 10,000,000 : Rush
# 10,000,000 : San Andreas Crime Stories
# 10,000,000 : Scratch Logo Quiz. Challenging brain puzzle
# 10,000,000 : Shoot Strike War Fire
# 10,000,000 : Shooting King
# 10,000,000 : 1LINE – One Line with One Touch
# 10,000,000 : Candy Bomb
# 10,000,000 : DINO HUNTER: DEADLY SHORES
# 10,000,000 : Five Nights at Freddy's 3 Demo
# 10,000,000 : Bullet Force
# 10,000,000 : Dr. Driving 2
# 10,000,000 : Dragon Hills
# 10,000,000 : Bubble Shooter
# 10,000,000 : Draw In
# 10,000,000 : Draw a Stickman: EPIC 2 Free
# 10,000,000 : Draw a Stickman: EPIC Free
# 10,000,000 : Dude Perfect 2
# 10,000,000 : Bounce Classic
# 10,000,000 : Experiment Z - Zombie
# 10,000,000 : Eyes - The Scary Horror Game Adventure
# 10,000,000 : Bomber Friends
# 10,000,000 : Blossom Blast Saga
# 10,000,000 : FRONTLINE COMMANDO
# 10,000,000 : FRONTLINE COMMANDO: D-DAY
# 10,000,000 : Family Guy The Quest for Stuff
# 10,000,000 : Fernanfloo
# 10,000,000 : Fidget Spinner
# 10,000,000 : Final Fantasy XV: A New Empire
# 10,000,000 : Dino T-Rex
# 10,000,000 : Defender
# 10,000,000 : Deck Heroes: Legacy
# 10,000,000 : Crisis Action: 2018 NO.1 FPS
# 10,000,000 : Color Road
# 10,000,000 : Counter Terrorist Attack
# 10,000,000 : Choices: Stories You Play
# 10,000,000 : Cover Fire: offline shooting games for free
# 10,000,000 : Checkers
# 10,000,000 : Cheating Tom 3 - Genius School
# 10,000,000 : Crazy Wheels
# 10,000,000 : Cash, Inc. Money Clicker Game & Business Adventure
# 10,000,000 : Critical Ops
# 10,000,000 : Dan the Man: Action Platformer
# 10,000,000 : Can Knockdown 3
# 10,000,000 : Call of Mini™ Dino Hunter
# 10,000,000 : Call of Duty®: Heroes
# 10,000,000 : DEER HUNTER 2018
# 10,000,000 : DH Texas Poker - Texas Hold'em
# 10,000,000 : Hustle Castle: Fantasy Kingdom
# 10,000,000 : DRAGON BALL Z DOKKAN BATTLE
# 10,000,000 : Bunny Skater
# 10,000,000 : Fishdom
# 10,000,000 : Block Strike
# 10,000,000 : Best Fiends - Free Puzzle Game
# 10,000,000 : Big Hunter
# 10,000,000 : Big Fish Casino – Play Slots & Vegas Games
# 10,000,000 : Battlefield™ Companion
# 10,000,000 : Gun Strike Shoot
# 10,000,000 : Baseball Boy!
# 10,000,000 : Guns of Boom - Online Shooter
# 10,000,000 : Guns of Glory
# 10,000,000 : BLACKJACK!
# 10,000,000 : BEYBLADE BURST app
# 10,000,000 : Hard Time (Prison Sim)
# 10,000,000 : Harry Potter: Hogwarts Mystery
# 10,000,000 : Heart of Vegas™ Slots – Free Slot Casino Games
# 10,000,000 : Hello Stars
# 10,000,000 : Asphalt Xtreme: Rally Racing
# 10,000,000 : Arrow.io
# 10,000,000 : Heroes Arena
# 10,000,000 : Arena of Valor: 5v5 Arena Game
# 10,000,000 : Hole.io
# 10,000,000 : Homescapes
# 10,000,000 : Alto's Adventure
# 10,000,000 : Grand Gangsters 3D
# 10,000,000 : Cooking Madness - A Chef's Restaurant Games
# 10,000,000 : Fruit Block - Puzzle Legend
# 10,000,000 : Bike Rivals
# 10,000,000 : Geometry Dash World
# 10,000,000 : Geometry Dash SubZero
# 10,000,000 : Gems or jewels ?
# 10,000,000 : Five Nights at Freddy's 4 Demo
# 10,000,000 : Flip the Gun - Simulator Game
# 10,000,000 : Fruits Bomb
# 10,000,000 : Bike Race - Bike Blast Rush
# 10,000,000 : Bike Mayhem Free
# 10,000,000 : Galaxy Attack: Alien Shooter
# 5,000,000 : Bingo by IGG: Top Bingo+Slots!
# 5,000,000 : The Visitor
# 5,000,000 : Color by Number – New Coloring Book
# 5,000,000 : Cartoon Wars: Blade
# 5,000,000 : Tiny Archers
# 5,000,000 : Wheelie Challenge
# 5,000,000 : Tomb of the Mask
# 5,000,000 : Call of Mini™ Zombies 2
# 5,000,000 : Angry Birds Space HD
# 5,000,000 : Chicken Invaders 3
# 5,000,000 : Toughest Game Ever 2
# 5,000,000 : Classic Words Solo
# 5,000,000 : AE 3D MOTOR :Racing Games Free
# 5,000,000 : Block Puzzle Classic Legend !
# 5,000,000 : Survival Run with Bear Grylls
# 5,000,000 : Asylum Night Shift - Five Nights Survival
# 5,000,000 : Super Jabber Jump 3
# 5,000,000 : Will it Crush?
# 5,000,000 : CONTRACT KILLER: ZOMBIES (NR)
# 5,000,000 : CONTRACT KILLER: ZOMBIES
# 5,000,000 : The Cube
# 5,000,000 : TEKKEN™
# 5,000,000 : War and Order
# 5,000,000 : Texas Holdem Poker Pro
# 5,000,000 : Block Puzzle
# 5,000,000 : THE KING OF FIGHTERS-A 2012(F)
# 5,000,000 : Bubble Shooter Genies
# 5,000,000 : Bubble Shooter 2
# 5,000,000 : Word Crossy - A crossword game
# 5,000,000 : Block Gun 3D: Ghost Ops
# 5,000,000 : I Know Stuff
# 5,000,000 : Commando Adventure Assassin
# 5,000,000 : Cops N Robbers - FPS Mini Game
# 5,000,000 : Nights at Cube Pizzeria 3D – 2
# 5,000,000 : New YAHTZEE® With Buddies Dice Game
# 5,000,000 : NARUTO X BORUTO NINJA VOLTAGE
# 5,000,000 : My OldBoy! Free - GBC Emulator
# 5,000,000 : Motocross Motorbike Simulator Offroad
# 5,000,000 : Four In A Line Free
# 5,000,000 : Mini Golf King - Multiplayer Game
# 5,000,000 : GUN ZOMBIE
# 5,000,000 : Merge Dragons!
# 5,000,000 : Gangster Town
# 5,000,000 : Glitch Fixers: Powerpuff Girls
# 5,000,000 : Mad Day - Truck Distance Game
# 5,000,000 : Golden HoYeah Slots - Real Casino Slots
# 5,000,000 : Governor of Poker 2 - OFFLINE POKER GAME
# 5,000,000 : Love Nikki-Dress UP Queen
# 5,000,000 : Grim Soul: Dark Fantasy Survival
# 5,000,000 : Guess The Emoji
# 5,000,000 : Lineage 2: Revolution
# 5,000,000 : Last Shelter: Survival
# 5,000,000 : HAWK – Force of an Arcade Shooter. Shoot 'em up
# 5,000,000 : Hambo
# 5,000,000 : Hero Hunters
# 5,000,000 : 4 in a row
# 5,000,000 : Jungle Marble Blast
# 5,000,000 : Jewels classic Prince
# 5,000,000 : Hopeless Land: Fight for Survival
# 5,000,000 : Injustice 2
# 5,000,000 : Fast like a Fox
# 5,000,000 : Oggy
# 5,000,000 : PRO MX MOTOCROSS 2
# 5,000,000 : DEER HUNTER RELOADED
# 5,000,000 : Counter Online FPS Game
# 5,000,000 : Snes9x EX+
# 5,000,000 : Smashy Road: Arena
# 5,000,000 : Crazy Bike attack Racing New: motorcycle racing
# 5,000,000 : Sky Streaker - Gumball
# 5,000,000 : Creative Destruction
# 5,000,000 : Shoot Bubble - Fruit Splash
# 5,000,000 : CrossFire: Legends
# 5,000,000 : SCRABBLE
# 5,000,000 : SAMURAI vs ZOMBIES DEFENSE
# 5,000,000 : Cytus
# 5,000,000 : DEER HUNTER CHALLENGE
# 5,000,000 : Rope Hero 3
# 5,000,000 : Peggle Blast
# 5,000,000 : DRAGON BALL LEGENDS
# 5,000,000 : Rivals at War: Firefight
# 5,000,000 : Rescue Robots Survival Games
# 5,000,000 : Dinosaur Simulator: Dino World
# 5,000,000 : Disney Heroes: Battle Mode
# 5,000,000 : Does not Commute
# 5,000,000 : Dr. Gomoku
# 5,000,000 : RC Monster Truck - Offroad Driving Simulator
# 5,000,000 : ETERNITY WARRIORS 2
# 5,000,000 : Evil Apples: A Dirty Card Game
# 5,000,000 : Extreme X Ray Robot Stunts
# 5,000,000 : FINAL FANTASY BRAVE EXVIUS
# 5,000,000 : Jurassic World™ Alive
#
#
# ----------------------------------------------------------------------------------------------------
# Android | TRAVEL_AND_LOCAL - high installs: 5
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Google Street View
# 1,000,000,000 : Maps - Navigate & Explore
# 100,000,000 : Booking.com Travel Deals
# 100,000,000 : Google Earth
# 100,000,000 : TripAdvisor Hotels Flights Restaurants Attractions
# ----------------------------------------------------------------------------------------------------
# Android | TRAVEL_AND_LOCAL - middle installs: 50
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : 2GIS: directory & navigator
# 50,000,000 : MAPS.ME – Offline Map and Travel Navigation
# 50,000,000 : VZ Navigator
# 50,000,000 : trivago: Hotels & Travel
# 10,000,000 : Airbnb
# 10,000,000 : Hotels.com: Book Hotel Rooms & Find Vacation Deals
# 10,000,000 : easyJet: Travel App
# 10,000,000 : Yelp: Food, Shopping, Services Nearby
# 10,000,000 : Yatra - Flights, Hotels, Bus, Trains & Cabs
# 10,000,000 : XE Currency
# 10,000,000 : Where is my Train : Indian Railway & PNR Status
# 10,000,000 : Agoda – Hotel Booking Deals
# 10,000,000 : Skyscanner
# 10,000,000 : PagesJaunes - local search
# 10,000,000 : NTES
# 10,000,000 : MakeMyTrip-Flight Hotel Bus Cab IRCTC Rail Booking
# 10,000,000 : AirAsia
# 10,000,000 : KakaoMap - Map / Navigation
# 10,000,000 : AT&T Navigator: Maps, Traffic
# 10,000,000 : Live Camera Viewer ★ World Webcam & IP Cam Streams
# 10,000,000 : KAYAK Flights, Hotels & Cars
# 10,000,000 : Goibibo - Flight Hotel Bus Car IRCTC Booking App
# 10,000,000 : Flightradar24 Flight Tracker
# 10,000,000 : Foursquare Swarm: Check In
# 10,000,000 : GPS Status & Toolbox
# 10,000,000 : GasBuddy: Find Cheap Gas
# 10,000,000 : Expedia Hotels, Flights & Car Rental Travel Deals
# 10,000,000 : Despegar.com Hotels and Flights
# 5,000,000 : Wisepilot for XPERIA™
# 5,000,000 : Fly Delta
# 5,000,000 : Flight & Hotel Booking App - ixigo
# 5,000,000 : VZ Navigator for Galaxy S4
# 5,000,000 : Cheapflights – Flight Search
# 5,000,000 : Cheap Flights & Hotels momondo
# 5,000,000 : Urbanspoon Restaurant Reviews
# 5,000,000 : United Airlines
# 5,000,000 : Southwest Airlines
# 5,000,000 : Hopper - Watch & Book Flights
# 5,000,000 : Scout GPS Navigation & Meet Up
# 5,000,000 : HotelTonight: Book amazing deals at great hotels
# 5,000,000 : Priceline Hotel Deals, Rental Cars & Flights
# 5,000,000 : Poynt
# 5,000,000 : Offline Maps & Navigation
# 5,000,000 : GPS Map Free
# 5,000,000 : American Airlines
# 5,000,000 : Google Trips - Travel Planner
# 5,000,000 : IndiGo
# 5,000,000 : HomeAway Vacation Rentals
# 5,000,000 : Hotels Combined - Cheap deals
# 5,000,000 : SNCF
#
#
# ----------------------------------------------------------------------------------------------------
# Android | ENTERTAINMENT - high installs: 5
# ----------------------------------------------------------------------------------------------------
# 100,000,000 : Hotstar
# 100,000,000 : IMDb Movies & TV
# 100,000,000 : Netflix
# 100,000,000 : Talking Angela
# 100,000,000 : Talking Ben the Dog
# ----------------------------------------------------------------------------------------------------
# Android | ENTERTAINMENT - middle installs: 35
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : Amazon Prime Video
# 50,000,000 : Twitch: Livestream Multiplayer Games & Esports
# 50,000,000 : Talking Ginger 2
# 50,000,000 : PlayStation App
# 10,000,000 : Mobile TV
# 10,000,000 : ivi - movies and TV shows in HD
# 10,000,000 : WWE
# 10,000,000 : Vudu Movies & TV
# 10,000,000 : Viki: Asian TV Dramas & Movies
# 10,000,000 : Tubi TV - Free Movies & TV
# 10,000,000 : SketchBook - draw and paint
# 10,000,000 : STARZ
# 10,000,000 : Redbox
# 10,000,000 : Movies by Flixster, with Rotten Tomatoes
# 10,000,000 : BBC Media Player
# 10,000,000 : Motorola Spotlight Player™
# 10,000,000 : MEGOGO - Cinema and TV
# 10,000,000 : CBS - Full Episodes & Live TV
# 10,000,000 : Colorfy: Coloring Book for Adults - Free
# 10,000,000 : Fandango Movies - Times + Tickets
# 10,000,000 : Crackle - Free TV & Movies
# 10,000,000 : FOX
# 10,000,000 : Imgur: Find funny GIFs, memes & watch viral videos
# 10,000,000 : Crunchyroll - Everything Anime
# 5,000,000 : DStv Now
# 5,000,000 : ColorFul - Adult Coloring Book
# 5,000,000 : Vigo Lite
# 5,000,000 : TV+
# 5,000,000 : Digital TV
# 5,000,000 : Spectrum TV
# 5,000,000 : FOX NOW - On Demand & Live TV
# 5,000,000 : Girly Lock Screen Wallpaper with Quotes
# 5,000,000 : Peers.TV: broadcast TV channels First, Match TV, TNT ...
# 5,000,000 : H TV
# 5,000,000 : YouTube Gaming
#
#
# ----------------------------------------------------------------------------------------------------
# Android | TOOLS - high installs: 29
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Google
# 500,000,000 : Security Master - Antivirus, VPN, AppLock, Booster
# 500,000,000 : SHAREit - Transfer & Share
# 500,000,000 : Google Translate
# 500,000,000 : Clean Master- Space Cleaner & Antivirus
# 500,000,000 : Gboard - the Google Keyboard
# 100,000,000 : 360 Security - Free Antivirus, Booster, Cleaner
# 100,000,000 : GO Keyboard - Cute Emojis, Themes and GIFs
# 100,000,000 : Speedtest by Ookla
# 100,000,000 : Share Music & Transfer Files - Xender
# 100,000,000 : Samsung Smart Switch Mobile
# 100,000,000 : Samsung Calculator
# 100,000,000 : Lookout Security & Antivirus
# 100,000,000 : Google Now Launcher
# 100,000,000 : Google Korean Input
# 100,000,000 : Device Help
# 100,000,000 : AVG AntiVirus 2018 for Android Security
# 100,000,000 : DU Battery Saver - Battery Charger & Battery Life
# 100,000,000 : Calculator
# 100,000,000 : Cache Cleaner-DU Speed Booster (booster & cleaner)
# 100,000,000 : CM Locker - Security Lockscreen
# 100,000,000 : Battery Doctor-Battery Life Saver & Battery Cooler
# 100,000,000 : Avast Mobile Security 2018 - Antivirus & App Lock
# 100,000,000 : Automatic Call Recorder
# 100,000,000 : Applock
# 100,000,000 : AppLock
# 100,000,000 : Anti-virus Dr.Web Light
# 100,000,000 : Account Manager
# 100,000,000 : Tiny Flashlight + LED
# ----------------------------------------------------------------------------------------------------
# Android | TOOLS - middle installs: 145
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : APUS File Manager (Explorer)
# 50,000,000 : Brightest Flashlight - LED Light
# 50,000,000 : QR Code Reader
# 50,000,000 : RAR
# 50,000,000 : Color Flashlight
# 50,000,000 : Clean Master Lite - For Low-End Phone
# 50,000,000 : My Telcel
# 50,000,000 : Motorola Assist
# 50,000,000 : Downloader & Private Browser
# 50,000,000 : Motorola Alert
# 50,000,000 : CM FILE MANAGER
# 50,000,000 : CCleaner
# 50,000,000 : SuperVPN Free VPN Client
# 50,000,000 : T-Mobile Visual Voicemail
# 50,000,000 : Brightest Flashlight Free ®
# 50,000,000 : Emoji keyboard - Cute Emoticons, GIF, Stickers
# 50,000,000 : Master for Minecraft(Pocket Edition)-Mod Launcher
# 50,000,000 : Kaspersky Mobile Antivirus: AppLock & Web Security
# 50,000,000 : Hotspot Shield Free VPN Proxy & Wi-Fi Security
# 50,000,000 : Flashlight HD LED
# 50,000,000 : DiskDigger photo recovery
# 50,000,000 : File Manager
# 50,000,000 : Video Downloader for Facebook
# 10,000,000 : LED Flashlight
# 10,000,000 : OpenVPN Connect – Fast & Safe SSL VPN Client
# 10,000,000 : ASUS Sound Recorder
# 10,000,000 : High-Powered Flashlight
# 10,000,000 : Norton Security and Antivirus
# 10,000,000 : MyScript Calculator
# 10,000,000 : My love
# 10,000,000 : Instabridge - Free WiFi Passwords and Hotspots
# 10,000,000 : Keypad Lock Screen
# 10,000,000 : Internet Speed Meter Lite
# 10,000,000 : MOD-MASTER for Minecraft PE (Pocket Edition) Free
# 10,000,000 : Moto Voice
# 10,000,000 : Moto File Manager
# 10,000,000 : Moto Display
# 10,000,000 : Mi Remote controller - for TV, STB, AC and more
# 10,000,000 : Keyboard ManMan
# 10,000,000 : Samsung Max - Data Savings & Privacy Protection
# 10,000,000 : Phone
# 10,000,000 : QR BARCODE SCANNER
# 10,000,000 : photo keypad lockscreen
# 10,000,000 : myMetro
# 10,000,000 : ZenUI Keyboard – Emoji, Theme
# 10,000,000 : ZenUI Help
# 10,000,000 : Zapya - File Transfer, Sharing
# 10,000,000 : ZArchiver
# 10,000,000 : X-plore File Manager
# 10,000,000 : Wifi Analyzer
# 10,000,000 : WPSApp
# 10,000,000 : WIFI WPS WPA TESTER
# 10,000,000 : VPN Free - Betternet Hotspot VPN & Private Browser
# 10,000,000 : Tuner - gStrings Free
# 10,000,000 : Terminal Emulator for Android
# 10,000,000 : T-Mobile
# 10,000,000 : Sound Recorder: Recorder & Voice Changer Free
# 10,000,000 : Sound Meter
# 10,000,000 : Solo Locker (DIY Locker)
# 10,000,000 : Smart TV Remote
# 10,000,000 : Smart Keyboard Trial
# 10,000,000 : Smart AppLock (App Protect)
# 10,000,000 : Screen Off and Lock
# 10,000,000 : Screen Lock - with Fingerprint Simulator
# 10,000,000 : Satellite Director
# 10,000,000 : HTC Lock Screen
# 10,000,000 : Remote Link (PC Remote)
# 10,000,000 : HTC Sense Input
# 10,000,000 : osmino Wi-Fi: free WiFi
# 10,000,000 : Clear
# 10,000,000 : DuraSpeed
# 10,000,000 : Dr. Safety - Antivirus, Booster, Cleaner, AppLock
# 10,000,000 : Dr. Booster - Boost Game Speed
# 10,000,000 : Download Manager for Android
# 10,000,000 : Download Manager
# 10,000,000 : Download All Files
# 10,000,000 : Antivirus & Mobile Security
# 10,000,000 : Digital Alarm Clock
# 10,000,000 : CM Security Lite - Antivirus
# 10,000,000 : App vault
# 10,000,000 : CPU-Z
# 10,000,000 : DU Cleaner – Memory cleaner & clean phone cache
# 10,000,000 : DU Antivirus Security - Applock & Privacy Guard
# 10,000,000 : AppLock - Fingerprint
# 10,000,000 : ConvertPad - Unit Converter
# 10,000,000 : Google app for Android TV
# 10,000,000 : Calculator - free calculator, multi calculator app
# 10,000,000 : Avast Cleanup & Boost, Phone Cleaner, Optimizer
# 10,000,000 : Calculator Plus Free
# 10,000,000 : Dr.Web Security Space
# 10,000,000 : Alarm Clock Free
# 10,000,000 : Files Go by Google: Free up space on your phone
# 10,000,000 : Google Handwriting Input
# 10,000,000 : AT&T FamilyMap®
# 10,000,000 : AT&T Smart Wi-Fi
# 10,000,000 : GO Security－AntiVirus, AppLock, Booster
# 10,000,000 : Advanced Download Manager
# 10,000,000 : Flashlight - Torch LED Light
# 10,000,000 : Flashlight & LED Torch
# 10,000,000 : Flashlight
# 10,000,000 : File Manager by Xiaomi: release file storage space
# 10,000,000 : File Manager -- Take Command of Your Files Easily
# 10,000,000 : FVD - Free Video Downloader
# 10,000,000 : Epson iPrint
# 10,000,000 : Easy Language Translator
# 10,000,000 : Card Creator for CR
# 5,000,000 : Turbo Download Manager (and Browser)
# 5,000,000 : Unseen - No Last Seen
# 5,000,000 : TunnelBear VPN
# 5,000,000 : Turbo Downloader
# 5,000,000 : BTNotification
# 5,000,000 : All Language Translator
# 5,000,000 : AppLock - Fingerprint Unlock
# 5,000,000 : AppFinder by AppTap
# 5,000,000 : Wifi Inspector
# 5,000,000 : X-VPN - Free Unlimited VPN Proxy
# 5,000,000 : Battery Calibration
# 5,000,000 : Alarm Clock
# 5,000,000 : dr.fone - Recovery & Transfer wirelessly & Backup
# 5,000,000 : iWnn IME for Nexus
# 5,000,000 : Translate: text & voice translator
# 5,000,000 : HSPA+ Tweaker (3G booster)
# 5,000,000 : Brightest LED Flashlight
# 5,000,000 : Don't touch my phone
# 5,000,000 : GetThemAll Any File Downloader
# 5,000,000 : HTC Transfer Tool
# 5,000,000 : Hideman VPN
# 5,000,000 : Fraction Calculator Plus Free
# 5,000,000 : Image 2 Wallpaper
# 5,000,000 : Mobi Calculator free & AD free!
# 5,000,000 : Mobile Number Tracker
# 5,000,000 : Download Blazer
# 5,000,000 : Nokia mobile support
# 5,000,000 : Deck Advisor for CR
# 5,000,000 : Bubble
# 5,000,000 : Phone X Launcher, OS 11 iLauncher & Control Center
# 5,000,000 : DU Flashlight - Brightest LED & Flashlight Free
# 5,000,000 : DS get
# 5,000,000 : Classic Calculator
# 5,000,000 : Chest Tracker for Clash Royale
# 5,000,000 : CM Flashlight (Compass, SOS)
# 5,000,000 : Super Flashlight + LED
# 5,000,000 : CALCU™ Stylish Calculator Free
# 5,000,000 : SurfEasy Secure Android VPN
# 5,000,000 : HTC Sense Input - EN
#
#
# ----------------------------------------------------------------------------------------------------
# Android | NEWS_AND_MAGAZINES - high installs: 3
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Google News
# 500,000,000 : Flipboard: News For Our Time
# 500,000,000 : Twitter
# ----------------------------------------------------------------------------------------------------
# Android | NEWS_AND_MAGAZINES - middle installs: 34
# ----------------------------------------------------------------------------------------------------
# 50,000,000 : Dailyhunt (Newshunt) - Latest News, Viral Videos
# 10,000,000 : News Republic
# 10,000,000 : NEW - Read Newspaper, News 24h
# 10,000,000 : Updates for Samsung - Android Update Versions
# 10,000,000 : Topbuzz: Breaking News, Videos & Funny GIFs
# 10,000,000 : SmartNews: Breaking News Headlines
# 10,000,000 : Reddit: Social News, Trending Memes & Funny Videos
# 10,000,000 : Read- Latest News, Information, Gossip and Politics
# 10,000,000 : Pulse Nabd - World News, Urgent
# 10,000,000 : Pocket
# 10,000,000 : Opera News - Trending news and videos
# 10,000,000 : Newsroom: News Worth Sharing
# 10,000,000 : NewsDog - Latest News, Breaking News, Local News
# 10,000,000 : News by The Times of India Newspaper - Latest News
# 10,000,000 : NYTimes - Latest News
# 10,000,000 : detikcom - Latest & Most Complete News
# 10,000,000 : CNN Breaking US & World News
# 10,000,000 : BBC News
# 10,000,000 : Fox News – Breaking News, Live Video & News Alerts
# 10,000,000 : BaBe - Read News
# 10,000,000 : Bloomberg: Market & Financial News
# 5,000,000 : BuzzFeed: News, Tasty, Quizzes
# 5,000,000 : Vietnam Today - Read online newspapers, the hottest news 24h
# 5,000,000 : USA TODAY
# 5,000,000 : The Guardian
# 5,000,000 : NBC News
# 5,000,000 : Apple Daily Apple News
# 5,000,000 : Daily Mail Online
# 5,000,000 : Podcast Addict
# 5,000,000 : Economic Times : Market News
# 5,000,000 : FRANCE 24
# 5,000,000 : Gnoche entertainment news · sports news is also free
# 5,000,000 : Le Monde, the continuous news
# 5,000,000 : AOL - News, Mail & Video
#
#
# ----------------------------------------------------------------------------------------------------
# Android | BOOKS_AND_REFERENCE - high installs: 5
# ----------------------------------------------------------------------------------------------------
# 1,000,000,000 : Google Play Books
# 100,000,000 : Amazon Kindle
# 100,000,000 : Audiobooks from Audible
# 100,000,000 : Bible
# 100,000,000 : Wattpad 📖 Free Books
# ----------------------------------------------------------------------------------------------------
# Android | BOOKS_AND_REFERENCE - middle installs: 28
# ----------------------------------------------------------------------------------------------------
# 10,000,000 : Wikipedia
# 10,000,000 : JW Library
# 10,000,000 : FBReader: Favorite Book Reader
# 10,000,000 : Moon+ Reader
# 10,000,000 : English Hindi Dictionary
# 10,000,000 : English Dictionary - Offline
# 10,000,000 : NOOK: Read eBooks & Magazines
# 10,000,000 : Dictionary.com: Find Definitions for English Words
# 10,000,000 : Oxford Dictionary of English : Free
# 10,000,000 : Dictionary - Merriam-Webster
# 10,000,000 : Dictionary
# 10,000,000 : Cool Reader
# 10,000,000 : Quran for Android
# 10,000,000 : Aldiko Book Reader
# 10,000,000 : Spanish English Translator
# 10,000,000 : Al-Quran (Free)
# 10,000,000 : Al'Quran Bahasa Indonesia
# 10,000,000 : Al Quran Indonesia
# 10,000,000 : HTC Help
# 5,000,000 : Read books online
# 5,000,000 : 50000 Free eBooks & Free AudioBooks
# 5,000,000 : English to Hindi Dictionary
# 5,000,000 : Al Quran : EAlim - Translations & MP3 Offline
# 5,000,000 : Dictionary - WordWeb
# 5,000,000 : Bible KJV
# 5,000,000 : Ancestry
# 5,000,000 : AlReader -any text book reader
# 5,000,000 : Ebook Reader

# %% [markdown]
# **VIDEO_PLAYERS (Yes)**
# - Không nhiều ứng dụng nằm ở phân khúc 1 (chỉ 9 ứng dụng), đứng đầu là những người khổng lồ như YouTube, Google Play.
# - Không có quá nhiều người không lồ khi xem tổng thể cả 2 phân khúc.
# - Ngoài trình xem video ra còn có nhiều kiểu ứng dụng liên quan đến video khác như tải video, trình sửa video.
#
# *--> Đây là một thể loại có tiềm năng cho chúng ta phát triển. Tôi đề xuất ứng dụng tải video tất cả các mạng xã hội và ứng dụng xem video thông qua YouTube nhưng không có quảng cáo gây gián đoạn, tất nhiên quảng cáo của chúng ta sẽ hiển thị một vị trí nào nó không ảnh hưởng người dùng.*
#
# **SOCIAL (No)**
#
# Nhìn chung thì những người khổng lồ đã chiếm hết thị trường của thể loại này. Việc thu hút ngươi dùng sử dụng một mạng xã hội mới mất rất nhiều công sức và chi phí, chúng ta nên bỏ qua thể loại này.
#
# **PHOTOGRAPHY (Yes)**
# - Có nhiều ứng dụng ở phân khúc 1 nhưng nhìn chung thì không có sự chi phối bởi những người không lồ. Vì vậy phân 2 vẫn còn cơ hội cho chúng ta.
# - Kho ứng dụng nhiếp ảnh trên Google Play đủ đáp ứng hầu hết nhu cầu dùng, chúng ta cần tìm ra những nhu cầu mới của người dùng và phát triển những tính năng khác biệt mới có thể thu hút được người dùng.
#
# *--> Tôi đề xuất một ứng dụng tự động xuất ra nhiều hình ảnh theo kích thước của tất cả các mạng xã hội trên thế giới, họ có thể chia sẻ hình ảnh lên các mạng xã hội với từng kích thước riêng để chúng hiển thị đẹp nhất ngay trong ứng dụng của chúng ta. Đồng thời có thể giúp họ thêm các lớp filter theo mùa, theo trend hoặc ngày lễ hội.*
#
# **PRODUCTIVITY (Yes)**
# - Phân khúc 1 đã có nhiều người không lồ chiếm lĩnh.
# - Nhưng phân khúc 2 thì không có nhiều người khổng lồ, chúng ta có cơ hội phát triển ở phân khúc này.
#
# *--> Tôi gợi ý một ứng dụng tích hợp hết mọi thứ có thể hỗ trợ PDF (convert to image, convert to text, convert to audio, tách một trang ra hoặc gộp nhiều trang lại, chỉnh sửa DPF, nén dung lượng PDF,...). Có rất nhiều nhu cầu của người dùng đối với PDF khi tìm hiểu bằng Google Keyword Suggest, việc chúng ta là tổng hợp tất cả nhu cầu lại và phát triển nó thành 1 ứng dụng chuyên nghiệp.*
#
# **GAME (Yes)**
#
# - Ở phân tích đầu tiên chúng ta đã đề xuất không phát triển thể loại trò chơi nữa vì có quá nhiều đối thủ và thị trường đang bão hòa.
# - Nhưng chúng ta sẽ đi một ngách khác ít cạnh tranh hơn để không bỏ qua người dùng ở thể này, đó là những cuốn cẩm nang chiến thuật chơi game.
#
# *--> Chúng ta có thể phát triển các ứng dụng cẩm nang để chơi các trò chơi khó. Khi người dùng tiềm kiếm một trò chơi, họ sẽ dễ tìm thấy ứng dụng chúng ta vì từ khóa giống nhau, ví dụ khi họ tìm `Wild Rift`, họ có thể thấy `Cẩm nang Wild Rift` của chúng ta.*
#
# *Việc của chúng ta cần làm là thu thập các trò chơi mang tính chiến thuật được nhiều người chơi nhất rồi tổng hợp các bí kiếp từ trên mạng thành một ứng dụng thú vị.*
#
# **TRAVEL_AND_LOCAL (No)**
# - Các ứng dụng trong thể loại này đỏi hỏi phải có kết nối API như bản đồ, điều này sẽ làm tăng chi phí.
# - Mặc dù không có nhiều ứng dụng trong phân khúc 1 và không có nhiều người khổng lồ trong thể loại, nhưng một công ty không liên quan đến du lịch như chúng ta sẽ khó phát triển được trong thể loại này.
#
# **ENTERTAINMENT (No)**
#
# - Mặc dù không có nhiều ứng dụng trong phân khúc 1 và không có nhiều người khổng lồ trong thể loại, nhưng thể loại này lại khó để cạnh tranh.
# - Bạn có thể thấy hầu hết các ứng dụng trong thể loại này liên quan đến xem phim trực tuyến. Nếu đầu tư vào kiểu ứng dụng này có thể khiến chúng ta mất nhiều chi phí như máy chủ để chứa phim. Nếu làm việc một cách đàng hoàng chúng ta còn phải mất chi phí bản quyền các bộ phim. Vì vậy tôi đề xuất chúng ta nên bỏ qua thể loại này.
#
# **TOOLS (Yes)**
# - Thể loại này rất đa dạng về ứng dụng, không bị những người khổng lồ chiếm lĩnh thị trường.
# - Để cạnh tranh ở thể loại này thì việc quan trọng là tìm ra nhu cầu mới của người dùng, hoặc những cải tiến vượt bậc so với các ứng dụng đang có trên Google Play.
#
# *--> Chúng ta có khả năng cạnh tranh ở phân khúc 2 của thể loại này.*
#
# **NEWS_AND_MAGAZINES (No)**
#
# Không có nhiều ứng dụng ở phân khúc 1, nhưng thể loại này cũng giống như ENTERTAINMENT. Chúng ta phải sản xuất nội dung online liên tục và cũng tốn chi phí không ít, một công ty viết ứng dụng rất khó cạnh tranh với các nhà báo về thể loại này. Vì vậy tôi đề xuất bỏ qua thể loại này.
#
# **BOOKS_AND_REFERENCE (Yes)**
# - Không có nhiều ứng dụng ở phân khúc 1. Nhìn chung ta có thể nhận ra rằng các ứng dụng chủ yếu trong thể loại này là dịch thuật, đọc sách online, một quyển sách nào đó.
# - Một quyển sách offline sẽ có nhiều cơ hội cho công ty của chúng ta hơn, nó cũng không đòi hỏi quá nhiều chi phí.
#
# *--> Tôi đề xuất phát triển các ứng dụng để đọc offline một quyển sách nổi tiếng nào đó. Hãy thêm nhiều tính năng hơn là một quyền sách thô, chẳng hạn như tăng - giảm kích cỡ chữ, lưu lại nơi đã đọc, highlight những câu trong sách, hiệu ứng lật trang sách, hoặc tuyệt vời hơn nữa là tính năng nghe audio offline của quyển sách đó.*
#
# #### Kết quả
# Chúng ta đã chọn được 6 thể loại ứng dụng trên Google Play để cho các nhà phát triển.
#
# 1. VIDEO_PLAYERS
# 2. PHOTOGRAPHY
# 3. PRODUCTIVITY
# 4. GAME (Cẩm nang)
# 5. TOOLS
# 6. BOOKS_AND_REFERENCE
#
# Nhưng chúng ta phải ưu tiên những thể loại thu hút nhiều người dùng trên cả 2 hệ điều hành Android và IOS, vì vậy hãy phân tích tiếp lượt đánh giá trung bình mỗi thể loại trên IOS để tìm ra thứ tự ưu tiên cho các thể loại ứng dụng.
#
# ### Số lượng đánh giá trung bình mỗi thể loại trên IOS

# %%
# Average Rating on App Store
pd.DataFrame(round(df_ios_english_free.groupby('prime_genre')['rating_count_tot'].sum() / df_ios_english_free.prime_genre.value_counts())).sort_values(by=0, ascending=False).set_axis(['Average ratings'],axis=1).style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4d723">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d723_level0_col0" class="col_heading level0 col0" >Average ratings</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d723_level0_row0" class="row_heading level0 row0" >Navigation</th>
#       <td id="T_4d723_row0_col0" class="data row0 col0" >86,090</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row1" class="row_heading level0 row1" >Reference</th>
#       <td id="T_4d723_row1_col0" class="data row1 col0" >74,942</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row2" class="row_heading level0 row2" >Social Networking</th>
#       <td id="T_4d723_row2_col0" class="data row2 col0" >71,548</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row3" class="row_heading level0 row3" >Music</th>
#       <td id="T_4d723_row3_col0" class="data row3 col0" >57,327</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row4" class="row_heading level0 row4" >Weather</th>
#       <td id="T_4d723_row4_col0" class="data row4 col0" >52,280</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row5" class="row_heading level0 row5" >Book</th>
#       <td id="T_4d723_row5_col0" class="data row5 col0" >39,758</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row6" class="row_heading level0 row6" >Food & Drink</th>
#       <td id="T_4d723_row6_col0" class="data row6 col0" >33,334</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row7" class="row_heading level0 row7" >Finance</th>
#       <td id="T_4d723_row7_col0" class="data row7 col0" >31,468</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row8" class="row_heading level0 row8" >Photo & Video</th>
#       <td id="T_4d723_row8_col0" class="data row8 col0" >28,442</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row9" class="row_heading level0 row9" >Travel</th>
#       <td id="T_4d723_row9_col0" class="data row9 col0" >28,244</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row10" class="row_heading level0 row10" >Shopping</th>
#       <td id="T_4d723_row10_col0" class="data row10 col0" >26,920</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row11" class="row_heading level0 row11" >Health & Fitness</th>
#       <td id="T_4d723_row11_col0" class="data row11 col0" >23,298</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row12" class="row_heading level0 row12" >Sports</th>
#       <td id="T_4d723_row12_col0" class="data row12 col0" >23,009</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row13" class="row_heading level0 row13" >Games</th>
#       <td id="T_4d723_row13_col0" class="data row13 col0" >22,813</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row14" class="row_heading level0 row14" >News</th>
#       <td id="T_4d723_row14_col0" class="data row14 col0" >21,248</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row15" class="row_heading level0 row15" >Productivity</th>
#       <td id="T_4d723_row15_col0" class="data row15 col0" >21,028</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row16" class="row_heading level0 row16" >Utilities</th>
#       <td id="T_4d723_row16_col0" class="data row16 col0" >18,684</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row17" class="row_heading level0 row17" >Lifestyle</th>
#       <td id="T_4d723_row17_col0" class="data row17 col0" >16,486</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row18" class="row_heading level0 row18" >Entertainment</th>
#       <td id="T_4d723_row18_col0" class="data row18 col0" >14,030</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row19" class="row_heading level0 row19" >Business</th>
#       <td id="T_4d723_row19_col0" class="data row19 col0" >7,491</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row20" class="row_heading level0 row20" >Education</th>
#       <td id="T_4d723_row20_col0" class="data row20 col0" >7,004</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row21" class="row_heading level0 row21" >Catalogs</th>
#       <td id="T_4d723_row21_col0" class="data row21 col0" >4,004</td>
#     </tr>
#     <tr>
#       <th id="T_4d723_level0_row22" class="row_heading level0 row22" >Medical</th>
#       <td id="T_4d723_row22_col0" class="data row22 col0" >612</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Nhìn vào Top 10 thể loại ứng dụng có lượt đánh giá trung bình cao nhất, chúng ta có thể thấy **Book** và **Photo & Video** là phù hợp với 6 thể loại đã chọn ở Google Play. Bây giờ chúng ta sẽ phân tích cụ thể từng thể loại.

# %%
# Show IOS apps by genre
def show_ios_apps(genre):
    df = df_ios_english_free
    cond = df.prime_genre == genre
    df_flltered = df[cond][['rating_count_tot','track_name']].sort_values(by='rating_count_tot', ascending=False).reset_index(drop=True)
    print(f'{"-"*88}\nIOS | {genre}: {df_flltered.shape[0]}\n{"-"*88}')
    for row in df_flltered.values:
        print(f'{row[0]:,} : {row[1]}')
    print('\n')

# %%
# Show all apps by genres
show_ios_apps('Navigation')
show_ios_apps('Reference')
show_ios_apps('Social Networking')
show_ios_apps('Music')
show_ios_apps('Weather')
show_ios_apps('Book')
show_ios_apps('Food & Drink')
show_ios_apps('Finance')
show_ios_apps('Photo & Video')
show_ios_apps('Travel')
# Out:
# ----------------------------------------------------------------------------------------------------
# IOS | Navigation: 6
# ----------------------------------------------------------------------------------------------------
# 345,046 : Waze - GPS Navigation, Maps & Real-time Traffic
# 154,911 : Google Maps - Navigation & Transit
# 12,811 : Geocaching®
# 3,582 : CoPilot GPS – Car Navigation & Offline Maps
# 187 : ImmobilienScout24: Real Estate Search in Germany
# 5 : Railway Route Search
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Reference: 18
# ----------------------------------------------------------------------------------------------------
# 985,920 : Bible
# 200,047 : Dictionary.com Dictionary & Thesaurus
# 54,175 : Dictionary.com Dictionary & Thesaurus for iPad
# 26,786 : Google Translate
# 18,418 : Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran
# 17,588 : New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition
# 16,849 : Merriam-Webster Dictionary
# 12,122 : Night Sky
# 8,535 : City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE)
# 4,693 : LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools
# 1,497 : GUNS MODS for Minecraft PC Edition - Mods Tools
# 826 : Guides for Pokémon GO - Pokemon GO News and Cheats
# 762 : WWDC
# 718 : Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free
# 14 : VPN Express
# 8 : Real Bike Traffic Rider Virtual Reality Glasses
# 0 : 教えて!goo
# 0 : Jishokun-Japanese English Dictionary & Translator
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Social Networking: 106
# ----------------------------------------------------------------------------------------------------
# 2,974,676 : Facebook
# 1,061,624 : Pinterest
# 373,519 : Skype for iPhone
# 351,466 : Messenger
# 334,293 : Tumblr
# 287,589 : WhatsApp Messenger
# 260,965 : Kik
# 177,501 : ooVoo – Free Video Call, Text and Voice
# 164,963 : TextNow - Unlimited Text + Calls
# 164,249 : Viber Messenger – Text & Call
# 112,778 : Followers - Social Analytics For Instagram
# 97,072 : MeetMe - Chat and Meet New People
# 90,414 : We Heart It - Fashion, wallpapers, quotes, tattoos
# 85,535 : InsTrack for Instagram - Analytics Plus More
# 75,412 : Tango - Free Video Call, Voice and Chat
# 71,856 : LinkedIn
# 60,659 : Match™ - #1 Dating App.
# 60,163 : Skype for iPad
# 52,642 : POF - Best Dating App for Conversations
# 49,510 : Timehop
# 43,877 : Find My Family, Friends & iPhone - Life360 Locator
# 39,819 : Whisper - Share, Express, Meet
# 36,404 : Hangouts
# 34,677 : LINE PLAY - Your Avatar World
# 34,584 : WeChat
# 34,428 : Badoo - Meet New People, Chat, Socialize.
# 28,633 : Followers + for Instagram - Follower Analytics
# 28,260 : GroupMe
# 27,662 : Marco Polo Video Walkie Talkie
# 23,965 : Miitomo
# 23,530 : SimSimi
# 23,201 : Grindr - Gay and same sex guys chat, meet and date
# 20,649 : Wishbone - Compare Anything
# 18,841 : imo video calls and chat
# 18,482 : After School - Funny Anonymous School News
# 17,694 : Quick Reposter - Repost, Regram and Reshare Photos
# 16,772 : Weibo HD
# 15,185 : Repost for Instagram
# 14,724 : Live.me – Live Video Chat & Make Friends Nearby
# 14,402 : Nextdoor
# 13,914 : Followers Analytics for Instagram - InstaReport
# 12,079 : YouNow: Live Stream Video Chat
# 11,976 : FollowMeter for Instagram - Followers Tracking
# 11,437 : LINE
# 11,124 : eHarmony™ Dating App - Meet Singles
# 9,152 : Discord - Chat for Gamers
# 9,109 : QQ
# 7,573 : Telegram Messenger
# 7,265 : Weibo
# 6,062 : Periscope - Live Video Streaming Around the World
# 5,060 : Chat for Whatsapp - iPad Version
# 5,058 : QQ HD
# 4,253 : Followers Analysis Tool For Instagram App Free
# 4,145 : live.ly - live video streaming
# 3,991 : Houseparty - Group Video Chat
# 3,232 : SOMA Messenger
# 3,060 : Monkey
# 2,535 : Down To Lunch
# 2,134 : Flinch - Video Chat Staring Contest
# 2,011 : Highrise - Your Avatar Community
# 1,985 : LOVOO - Dating Chat
# 1,918 : PlayStation®Messages
# 1,805 : BOO! - Video chat camera with filters & stickers
# 1,649 : Qzone
# 1,609 : Chatous - Chat with new people
# 1,538 : Kiwi - Q&A
# 1,313 : GhostCodes - a discovery app for Snapchat
# 1,193 : Jodel
# 1,037 : FireChat
# 1,033 : Google Duo - simple video calling
# 885 : Fiesta by Tango - Chat & Meet New People
# 862 : Google Allo — smart messaging
# 727 : Peach — share vividly
# 719 : Hey! VINA - Where Women Meet New Friends
# 689 : Battlefield™ Companion
# 682 : All Devices for WhatsApp - Messenger for iPad
# 500 : Chat for Pokemon Go - GoChat
# 463 : IAmNaughty – Dating App to Meet New People Online
# 458 : Qzone HD
# 427 : Zenly - Locate your friends in realtime
# 420 : League of Legends Friends
# 407 : 豆瓣
# 398 : Candid - Speak Your Mind Freely
# 397 : 知乎
# 366 : Selfeo
# 354 : Fake-A-Location Free ™
# 281 : Popcorn Buzz - Free Group Calls
# 279 : Fam — Group video calling for iMessage
# 274 : QQ International
# 269 : Ameba
# 240 : SoundCloud Pulse: for creators
# 235 : Tantan
# 213 : Cougar Dating & Life Style App for Mature Women
# 180 : Rawr Messenger - Dab your chat
# 158 : WhenToPost: Best Time to Post Photos for Instagram
# 147 : Inke—Broadcast an amazing life
# 53 : Mustknow - anonymous video Q&A
# 39 : CTFxCmoji
# 36 : Lobi
# 35 : Chain: Collaborate On MyVideo Story/Group Video
# 7 : botman - Real time video chat
# 0 : BestieBox
# 0 : MATCH ON LINE chat
# 0 : niconico ch
# 0 : LINE BLOG
# 0 : bit-tube - Live Stream Video Chat
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Music: 66
# ----------------------------------------------------------------------------------------------------
# 1,126,879 : Pandora - Music & Radio
# 878,563 : Spotify Music
# 402,925 : Shazam - Discover music, artists, videos & lyrics
# 293,228 : iHeartRadio – Free Music & Radio Stations
# 135,744 : SoundCloud - Music & Audio
# 131,695 : Magic Piano by Smule
# 119,316 : Smule Sing!
# 110,420 : TuneIn Radio - MLB NBA Audiobooks Podcasts Music
# 106,235 : Amazon Music
# 82,602 : SoundHound Song Search & Music Player
# 48,905 : Sonos Controller
# 30,845 : Bandsintown Concerts
# 28,606 : Karaoke - Sing Karaoke, Unlimited Songs!
# 26,286 : My Mixtapez Music
# 26,227 : Sing Karaoke Songs Unlimited with StarMaker
# 25,403 : Ringtones for iPhone & Ringtone Maker
# 25,193 : Musi - Unlimited Music For YouTube
# 18,202 : AutoRap by Smule
# 15,053 : Spinrilla - Mixtapes For Free
# 14,268 : Napster - Top Music & Radio
# 13,580 : edjing Mix:DJ turntable to remix and scratch music
# 13,443 : Free Music - MP3 Streamer & Playlist Manager Pro
# 13,016 : Free Piano app by Yokee
# 10,118 : Google Play Music
# 9,975 : Certified Mixtapes - Hip Hop Albums & Mixtapes
# 7,398 : TIDAL
# 7,109 : YouTube Music
# 5,196 : Nicki Minaj: The Empire
# 5,126 : Sounds app - Music And Friends
# 5,004 : SongFlip - Free Music Streamer
# 4,787 : Simple Radio - Live AM & FM Radio Stations
# 4,677 : Deezer - Listen to your Favorite Music & Playlists
# 4,013 : Ringtones for iPhone with Ringtone Maker
# 3,687 : Bose SoundTouch
# 3,018 : Amazon Alexa
# 2,815 : DatPiff
# 2,570 : Trebel Music - Unlimited Music Downloader
# 2,496 : Free Music Play - Mp3 Streamer & Player
# 2,487 : Acapella from PicPlayPost
# 2,416 : Coach Guitar - Lessons & Easy Tabs For Beginners
# 2,211 : Musicloud - MP3 and FLAC Music Player for Cloud Platforms.
# 1,636 : Piano - Play Keyboard Music Games with Magic Tiles
# 1,375 : Boom: Best Equalizer & Magical Surround Sound
# 1,246 : Music Freedom - Unlimited Free MP3 Music Streaming
# 1,047 : AmpMe - A Portable Social Party Music Speaker
# 933 : Medly - Music Maker
# 915 : Bose Connect
# 909 : Music Memos
# 612 : UE BOOM
# 555 : LiveMixtapes
# 355 : NOISE
# 329 : MP3 Music Player & Streamer for Clouds
# 320 : Musical Video Maker - Create Music clips lip sync
# 319 : Cloud Music Player - Downloader & Playlist Manager
# 288 : Remixlive - Remix loops with pads
# 224 : QQ音乐HD
# 158 : Blocs Wave - Make & Record Music
# 150 : PlayGround • Music At Your Fingertips
# 135 : Music and Chill
# 130 : The Singing Machine Mobile Karaoke App
# 64 : radio.de - Der Radioplayer
# 46 : Free Music -  Player & Streamer  for Dropbox, OneDrive & Google Drive
# 38 : NRJ Radio
# 17 : Smart Music: Streaming Videos and Radio
# 13 : BOSS Tuner
# 0 : PetitLyrics
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Weather: 28
# ----------------------------------------------------------------------------------------------------
# 495,626 : The Weather Channel: Forecast, Radar & Alerts
# 208,648 : The Weather Channel App for iPad – best local forecast, radar map, and storm tracking
# 188,583 : WeatherBug - Local Weather, Radar, Maps, Alerts
# 150,158 : MyRadar NOAA Weather Radar Forecast
# 144,214 : AccuWeather - Weather for Life
# 112,603 : Yahoo Weather
# 49,192 : Weather Underground: Custom Forecast & Local Radar
# 45,696 : NOAA Weather Radar - Weather Forecast & HD Radar
# 35,702 : Weather Live Free - Weather Forecast & Alerts
# 22,792 : Storm Radar
# 6,081 : QuakeFeed Earthquake Map, Alerts, and News
# 2,333 : Moji Weather - Free Weather Forecast
# 1,158 : Hurricane by American Red Cross
# 375 : Forecast Bar
# 203 : Hurricane Tracker WESH 2 Orlando, Central Florida
# 128 : FEMA
# 80 : iWeather - World weather forecast
# 78 : Weather - Radar - Storm with Morecast App
# 53 : Yurekuru Call
# 37 : Weather & Radar
# 25 : WRAL Weather Alert
# 24 : Météo-France
# 22 : JaxReady
# 14 : Freddy the Frogcaster's Weather Station
# 12 : Almanac Long-Range Weather Forecast
# 0 : TodayAir
# 0 : wetter.com
# 0 : WarnWetter
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Book: 14
# ----------------------------------------------------------------------------------------------------
# 252,076 : Kindle – Read eBooks, Magazines & Textbooks
# 105,274 : Audible – audio books, original series & podcasts
# 84,062 : Color Therapy Adult Coloring Book for Adults
# 65,450 : OverDrive – Library eBooks and Audiobooks
# 47,829 : HOOKED - Chat Stories
# 879 : BookShout: Read eBooks & Track Your Reading Goals
# 451 : Dr. Seuss Treasury — 50 best kids books
# 392 : Green Riding Hood
# 197 : Weirdwood Manor
# 9 : MangaZERO - comic reader
# 0 : ikouhoushi
# 0 : MangaTiara - love comic reader
# 0 : 謎解き
# 0 : 謎解き2016
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Food & Drink: 26
# ----------------------------------------------------------------------------------------------------
# 303,856 : Starbucks
# 258,624 : Domino's Pizza USA
# 113,936 : OpenTable - Restaurant Reservations
# 109,349 : Allrecipes Dinner Spinner
# 25,947 : DoorDash - Food Delivery
# 17,865 : UberEATS: Uber for Food Delivery
# 9,519 : Postmates - Food Delivery, Faster
# 9,068 : Dunkin' Donuts - Get Offers, Coupons & Rewards
# 5,665 : Chick-fil-A
# 4,050 : McDonald's
# 1,702 : Deliveroo: Restaurant Delivery - Order Food Nearby
# 1,645 : SONIC Drive-In
# 1,625 : Nowait Guest
# 1,356 : 7-Eleven, Inc.
# 805 : Outback
# 750 : Bon Appetit
# 457 : Starbucks Keyboard
# 197 : Whataburger
# 154 : Delish Eatmoji Keyboard
# 29 : Lieferheld - Delicious food delivery service
# 29 : Lieferando.de
# 22 : McDo France
# 20 : Chefkoch - Rezepte, Kochen, Backen & Kochbuch
# 9 : Youmiam
# 2 : Marmiton Twist
# 1 : Open Food Facts
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Finance: 36
# ----------------------------------------------------------------------------------------------------
# 233,270 : Chase Mobile℠
# 232,940 : Mint: Personal Finance, Budget, Bills & Money
# 119,773 : Bank of America - Mobile Banking
# 119,487 : PayPal - Send and request money safely
# 101,679 : Credit Karma: Free Credit Scores, Reports & Alerts
# 56,110 : Capital One Mobile
# 48,822 : Citi Mobile®
# 43,064 : Wells Fargo Mobile
# 34,322 : Chase Mobile
# 23,775 : Square Cash - Send Money for Free
# 21,858 : Capital One for iPad
# 21,090 : Venmo
# 19,946 : USAA Mobile
# 17,516 : TaxCaster – Free tax refund calculator
# 11,421 : Amex Mobile
# 9,635 : TurboTax Tax Return App - File 2016 income taxes
# 7,569 : Bank of America - Mobile Banking for iPad
# 2,207 : Wells Fargo for iPad
# 1,655 : Stash Invest: Investing & Financial Education
# 1,506 : Digit: Save Money Without Thinking About It
# 1,329 : IRS2Go
# 1,019 : Capital One CreditWise - Credit score and report
# 790 : U by BB&T
# 768 : Paribus - Rebates When Prices Drop
# 623 : KeyBank Mobile
# 434 : VyStar Mobile Banking for iPhone
# 77 : Sparkasse - Your mobile branch
# 57 : VyStar Mobile Banking for iPad
# 44 : Zaim
# 17 : Ma Banque
# 17 : Lloyds Bank Mobile Banking
# 10 : Suica
# 8 : Halifax Mobile Banking
# 8 : La Banque Postale
# 0 : 币优铺
# 0 : Impots.gouv
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Photo & Video: 160
# ----------------------------------------------------------------------------------------------------
# 2,161,558 : Instagram
# 323,905 : Snapchat
# 278,166 : YouTube - Watch Videos, Music, and Live Streams
# 123,433 : Pic Collage - Picture Editor & Photo Collage Maker
# 123,268 : Funimate video editor: add cool effects to videos
# 105,429 : musical.ly - your video social network
# 93,781 : Photo Collage Maker & Photo Editor - Live Collage
# 90,355 : Vine Camera
# 88,742 : Google Photos - unlimited photo and video storage
# 79,905 : Flipagram
# 54,282 : Mixgram - Picture Collage Maker - Pic Photo Editor
# 51,427 : Shutterfly: Prints, Photo Books, Cards Made Easy
# 51,330 : Pic Jointer – Photo Collage, Camera Effects Editor
# 45,320 : Color Pop Effects - Photo Editor & Picture Editing
# 40,531 : Photo Grid - photo collage maker & photo editor
# 39,722 : iSwap Faces LITE
# 39,501 : MOLDIV - Photo Editor, Collage & Beauty Camera
# 39,501 : Photo Editor by Aviary
# 34,585 : Photo Lab: Picture Editor, effects & fun face app
# 33,921 : Rookie Cam - Photo Editor & Filter Camera
# 32,558 : FotoRus -Camera & Photo Editor & Pic Collage Maker
# 29,078 : PicsArt Photo Studio: Collage Maker & Pic Editor
# 28,654 : Quik – GoPro Video Editor to edit clips with music
# 28,189 : Splice - Video Editor + Movie Maker by GoPro
# 26,060 : FreePrints – Photos Delivered
# 25,683 : Triller - Music Video & Film Maker
# 18,316 : Ghost Lens+Scary Photo Video Edit&Collage Maker
# 16,729 : Camera360 - Selfie Filter Camera, Photo Editor
# 16,221 : InstaMag - Free Pic and Photo Collage Maker
# 16,221 : Over— Edit Photos, Add Text & Captions to Pictures
# 15,654 : Photo Transfer App - Easy backup of photos+videos
# 15,605 : InstaSize: Photo Editor, Picture Effects & Collage
# 15,060 : Prisma: Photo Editor, Art Filters Pic Effects
# 14,744 : Filterra – Photo Editor, Effects for Pictures
# 14,188 : YouCam Makeup: Magic Makeup Selfie Cam
# 12,982 : MSQRD — Live Filters & Face Swap for Video Selfies
# 12,963 : Artisto – Video and Photo Editor with Art Filters
# 12,779 : InShot Video Editor Music, No Crop, Cut
# 12,616 : Layout from Instagram
# 11,977 : Face Swap App- Funny Face Changer Photo Effects
# 11,955 : Moments - private albums with friends and family
# 11,174 : VSCO
# 11,021 : Retrica - Selfie Camera with Filter, Sticker & GIF
# 10,618 : VivaVideo - Best Video Editor & Photo Movie Maker
# 10,511 : Prime Photos from Amazon
# 9,114 : Canva - Graphic Design & Photo Editing
# 9,095 : Photo Editor-
# 8,683 : Snapseed
# 8,520 : You Doodle - draw on photos & pictures, add text
# 8,454 : PIP Camera-Selfie Cam&Pic Collage&Photo Editor
# 7,503 : BeautyPlus - Selfie Camera for a Beautiful Image
# 6,700 : Baby Story - Pregnancy Pics Baby Milestones Photo
# 6,542 : Capture - Control Your GoPro Camera - Share Video
# 6,478 : Meitu
# 5,767 : Visage makeup editor plus photo teeth whitener
# 5,676 : Video & TV Cast for Chromecast: Best Browser to cast and stream webvideos and local videos on TV & Displays
# 5,253 : Adobe Photoshop Mix - Cut out, combine, create
# 5,112 : Collageable - Photo Collage Maker, Pic Grid Free
# 4,909 : Bazaart Photo Editor Pro and Picture Collage Maker
# 4,818 : InstaBeauty -Camera&Photo Editor&Pic Collage Maker
# 4,293 : YouCam Perfect - Photo & Selfie Editor
# 4,280 : PHHHOTO - Look Alive
# 4,267 : MuseCam - Edit Photos & Manual Camera
# 4,142 : VR Tube - Virtual Reality 360 Video Player
# 4,126 : Fyuse - 3D Photos
# 3,987 : MakeupPlus - Natural, Professional Makeup Looks
# 3,978 : LINE Camera - Photo editor, Animated Stamp, Filter
# 3,909 : Printicular Print Photos - 1 Hour Pickup
# 3,896 : Lumyer - augmented reality camera effects
# 3,711 : KODAK Kiosk Connect App
# 3,694 : Cool Wallpapers for Pokemon
# 3,668 : Pro Editor - Video Maker for FaceBook & Youtube
# 3,507 : Lomotif Music Video Editor - Add Music & Effects!
# 2,838 : Epson iPrint
# 2,522 : YouCam Fun - Live Selfie Video Filters
# 2,436 : A Color Story
# 2,373 : Boomerang from Instagram
# 2,275 : B612 - Trendy Filters, Selfiegenic Camera
# 2,246 : Polarr Photo Editor - Photo Editing Tools for All
# 2,235 : Retouch Vogue - Facetune Wrinkles & Pimples Makeup
# 2,177 : Kanvas - Express Yourself
# 2,159 : Easy Save - Repost your Instagram Photos & Videos
# 2,150 : Meitu HD
# 2,099 : Pixlr - Photo Collages, Effects, Overlays, Filters
# 2,092 : Patternator Pattern Maker Backgrounds & Wallpapers
# 2,082 : BeautyCam - AR Carnie selfie
# 2,069 : GIPHY. The GIF Search Engine for All the GIFs
# 2,005 : Adobe Photoshop Lightroom for iPad
# 1,952 : SuperPhoto - Photo Effects & Filters
# 1,799 : Solo Selfie
# 1,724 : Felt: Birthday & Greeting Cards & Thank You Card
# 1,646 : Perfect Image - Pic Collage Maker, Add Text to Photo, Cool Picture Editor
# 1,571 : InstaBoard  for Instagram - photos & videos repost
# 1,494 : Adobe Photoshop Lightroom for iPhone
# 1,421 : PhotoScan - scanner by Google Photos
# 1,274 : RealTimes: Video Maker
# 1,190 : Meipai
# 1,149 : POTO - Photo Collage Maker
# 1,115 : SNOW - Selfie, Motion sticker, Fun camera
# 1,035 : Bestie-Beauty Camera 360 & Portrait Selfie Editor
# 1,009 : Facetune 2
# 968 : Pitu
# 938 : intoLive - Custom Live Photos wallpaper maker
# 849 : LOL Movie: Change your face + voice!
# 830 : Camcorder - Record VHS Home Videos
# 807 : Anime Power FX
# 778 : Squaready for Video - Convert Rectangle Movie Clip into Square Shape for Instagram
# 689 : Canon PRINT Inkjet/SELPHY
# 678 : Microsoft Pix Camera
# 668 : Kwai - Share your video moments
# 631 : Polaroid Print App - ZIP
# 599 : Photo Quilt - Auto Collage Maker
# 523 : Cymera - Photo & Beauty Editor & Collage
# 514 : FACIE
# 422 : Photo Editing Effects & Collage Maker - Effectshop
# 415 : Pic-it Collage - Photo Collage Maker and Editor
# 397 : Candy Camera
# 375 : Microsoft Selfie
# 352 : Color Pop Free - Selective Color Splash Effects and Black & White Photography Editor
# 252 : SelfieCity
# 243 : InstaSave for Instagram - Download & Repost your own Videos & Photos for Free
# 228 : CATCHY Photos-Easter Bunny, Tooth Fairy and more..
# 222 : SW/NG - Living Photos. Memories that Swing.
# 220 : SlideStory - Create a slideshow movie and a snap video
# 165 : April - Layouts, Photo Collage, and Poster Maker
# 160 : PopCam　Photo
# 144 : Foodie - Delicious Camera for Food
# 134 : FreeVRPlayer
# 120 : Confetti - Geofilter Design Maker for Snapchat
# 103 : Philm-Video&Photo Editor,REAL-TIME Magic Filter
# 102 : Digital Domain
# 100 : Homido 360 VR player
# 88 : Best 9 for Instagram
# 88 : VR Video World - Virtual Reality
# 66 : FilmStory - For All Your Video Editing Needs
# 65 : GIFYme - Create video loops and gifs with amazing filters for Whatsapp and Instagram
# 58 : Kiosk Photo Transfer by Fujifilm
# 56 : Pikazo – AI art that YOU control
# 51 : lollicam - photo, video, and selfie camera
# 25 : LOOKS - Real Makeup Camera
# 21 : C CHANNEL -Watch tips & tricks videos for girls
# 16 : in-capturing moments in life
# 15 : Everfilter - transform your photos into artworks
# 12 : GoSnaps - Share Screenshots for Pokémon GO
# 9 : NightShooting
# 6 : MixChannel
# 3 : Simple Camera - Fast Minimal Design
# 2 : SwapperFace - Face Swap Free, Live Mask Effects
# 1 : Video speed editor - VBooster
# 1 : Video Smith - A Powerful video editing tool set
# 1 : LINE Moments - Capture Your Fun Moments
# 0 : MeiCam -  Video Production Master
# 0 : Instant X - Take instant-camera-like photo with double exposure and bulb mode
# 0 : EOPAN
# 0 : StageCameraHD
# 0 : Pictalive for Live Photos - Create from videos
# 0 : BlurEffect-Blur Photo & Video, Hide Face
# 0 : camera for filter
# 0 : Emojil - original emoji stamp, decoration camera
# 0 : CelebrityDiagnosis!
#
#
# ----------------------------------------------------------------------------------------------------
# IOS | Travel: 40
# ----------------------------------------------------------------------------------------------------
# 446,185 : Google Earth
# 223,885 : Yelp - Nearby Restaurants, Shopping & Services
# 145,549 : GasBuddy
# 56,194 : TripAdvisor Hotels Flights Restaurants
# 49,466 : Uber
# 46,922 : Lyft
# 32,341 : HotelTonight - Great Deals on Last Minute Hotels
# 31,261 : Hotels & Vacation Rentals by Booking.com
# 30,552 : Southwest Airlines
# 22,302 : Airbnb
# 10,278 : Expedia Hotels, Flights & Vacation Package Deals
# 8,094 : Fly Delta
# 6,944 : Hopper - Predict, Watch & Book Flights
# 5,748 : United Airlines
# 1,851 : Skiplagged — Actually Cheap Flights & Hotels
# 1,839 : Viator Tours & Activities
# 1,798 : iExit Interstate Exit Guide
# 1,482 : Gogo Entertainment
# 1,450 : Google Street View
# 912 : Webcams – EarthCam
# 685 : HISTORY Here
# 512 : DB Navigator
# 494 : Mobike - Dockless Bike Share
# 493 : MiFlight™ – Airport security line wait times at checkpoints for domestic and international travelers
# 397 : BlaBlaCar - Trusted Carpooling
# 353 : Six Flags
# 329 : Google Trips – Travel planner
# 268 : Voyages-sncf.com : book train and bus tickets
# 248 : Trainline UK: Live Train Times, Tickets & Planner
# 188 : Urlaubspiraten
# 177 : 铁路12306
# 175 : Ryanair - Cheapest Fares
# 154 : 飞猪
# 105 : Fleet Air Travel Guide & Airport Directory
# 92 : FlixBus - bus travel in Europe
# 22 : Ab in den Urlaub – Pauschalreisen günstig buchen
# 7 : SNCF
# 0 : skyticket - Reserve Best Valued Air Tickets
# 0 : Fluege.de - Finde den billigsten Flug
# 0 : VoiceTra(Voice Translator)

# %% [markdown]
# **Navigation (No)**
#
# Có khá ít ứng dụng trong thể loại này nhưng chủ yếu chúng là ứng dụng bản đồ, việc phát triển một ứng dụng bản đồ sẽ mất rất nhiều chi phí như API chẳng hạn. Vì vậy chúng ta nên bỏ qua thể lại này.
#
# **Reference (Yes)**
#
# Thể loại này là hỗn hợp giữa sách, dịch thuật, và một vài trò chơi. Nhưng có thẻ thấy rằng quyển sách Bible được nhiều lượt đánh giá nhất.
#
# *--> Thể loại này như một lần nữa ủng hộ đề xuất của tôi về việc chuyển các quyển sách nổi tiếng thành ứng dụng offline.*
#
# **Social Networking (No)**
#
# Tương tự như thể loại COMMUNICATION của Google Play, có quá nhiều người không lồ đang thống trị thể loại này. Chúng ta nên bỏ qua.
#
# **Music (Yes)**
#
# - Nếu làm một trình nghe nhạc online, chúng ta sẽ mất nhiều chi phí để lưu trữ bài hát.
# - Nhưng nếu làm một trình nghe nhạc offline thì cũng khó tiếp cận được người dùng vì IOS bị hạn chế chia sẻ nhạc giữa các ứng dụng khác nhau.
# - Nếu như có thể làm một trình nghe nhạc online mà dựa vào nguồn khác như YouTube thì có thể tiếp cận được người dùng hơn.
#
# *--> Xem lại phân tích thể loại VIDEO_PLAYERS của Google Play, tôi đã đề xuất một ứng dụng xem video YouTube không quảng cáo, bây giờ chúng ta có thể bổ sung thêm một vài tính năng lên quan đến nghe nhạc từ YouTube, ví dụ như người dùng có thể nghe nhạc YouTube trong khi tắt màn hình điện thoại.*
#
# **Weather (No)**
# - Phát triển các ứng dụng thời tiết cũng mất nhiều chi phí về API.
# - Người dùng cũng rất ít khi mở ứng dụng thời tiết ra để xem, mà doanh thu của chúng ta đến từ hiển thị quảng cáo trong ứng dụng.
#
# Vì vậy chúng ta nên bỏ qua thể loại này.
#
# **Book (Yes)**
#
# Có thể thấy một vài quyển sách đã được chuyển thành ứng dụng trong thể loại này, nhưng không nhiều. Chúng ta sẽ chọn thể loại này vì chúng ta phân tích và đề xuất ứng dụng rồi.
#
# **Food & Drink (No)**
#
# Hầu các ứng dụng trong thể loại liên quan đến giao hàng, và đặt thức ăn online. Thể loại này không phù hợp với công ty của chúng ta.
#
# **Finance (No)**
#
# Các ứng dụng trong thể loại này đều liên quan đến tài chính và ngân hàng, đây không phải là một điểm mạnh của công ty chúng ta.
#
# **Photo & Video (Yes)**
#
# Chúng ta đã chọn thể loại PHOTOGRAPHY khi phân tích ứng dụng trên Google Play và đã có đề xuất ý tưởng ứng dụng.
#
# **Travel (No)**
#
# Tương tự như phân tích về thể loại TRAVEL_AND_LOCAL của Google Play, nên chúng ta sẽ bỏ qua thể loại này.
#
# #### Kết quả
# Chúng ta đã chọn được 4 thể loại ứng dụng trên App Store cho các nhà phát triển.
# 1. Reference
# 2. Music
# 3. Book
# 4. Photo & Video
#
# ## Tóm lại các đề xuất
#
# ### Các thể loại ứng dụng được ưu tiên
#
# Các thể loại này sẽ được ưu tiên phát triển vì chúng có ứng dụng giống nhau và đều thu hút nhiều người dùng nhất trên cả 2 hệ điều hành.
#
# **VIDEO_PLAYERS | Music**
#
# Ứng dụng đề xuất là trình xem video và nghe nhạc từ nguồn của YouTube, không có quảng cáo gây gián đoạn, người dùng có thể nghe nhạc từ YouTube khi tắt màn hình điện thoại.
#
# **PHOTOGRAPHY | Photo & Video**
#
# Ứng dụng tự động xuất ra nhiều hình ảnh theo kích thước của tất cả các mạng xã hội trên thế giới, họ có thể chia sẻ hình ảnh lên các mạng xã hội với từng kích thước riêng để chúng hiển thị đẹp nhất ngay trong ứng dụng của chúng ta. Đồng thời có thể giúp họ thêm các lớp filter theo mùa, theo trend hoặc ngày lễ hội.
#
# **BOOKS_AND_REFERENCE | Reference, Book**
#
# Ứng dụng để đọc offline một quyển sách nổi tiếng nào đó. Hãy thêm nhiều tính năng hơn là một quyền sách thô, chẳng hạn như tăng - giảm kích cỡ chữ, lưu lại nơi đã đọc, highlight những câu trong sách, hiệu ứng lật trang sách, hoặc tuyệt vời hơn nữa là tính năng nghe audio offline của quyển sách đó.
#
# ### Các thể loại ứng dụng dự phòng
#
# **PRODUCTIVITY**
#
# Ứng dụng tích hợp hết mọi thứ có thể hỗ trợ PDF (convert to image, convert to text, convert to audio, tách một trang ra hoặc gộp nhiều trang lại, chỉnh sửa DPF, nén dung lượng PDF,...) có rất nhiều nhu cầu của người dùng đối với PDF, việc chúng ta cần là tổng hợp tất cả nhu cầu lại và phát triển nó thành 1 ứng dụng miễn phí.
#
# **GAME**
#
# Ứng dụng cẩm nang để chơi các trò chơi khó. Khi người dùng tiềm kiếm tên của một trò chơi, họ sẽ dễ dàng tìm thấy chúng ta nếu như tên của ứng dụng cũng chứa từ khóa là tên của trò chơi đó. Ví dụ khi họ tìm trò chơi Wild Rift, họ có thể thấy Cẩm nang Wild Rift của chúng ta. Việc của chúng ta cần làm là thu thập các trò chơi mang tính chiến thuật được nhiều người chơi nhất rồi tổng hợp các bí kiếp từ trên mạng thành một ứng dụng.
#
# **TOOLS**
#
# Cần nghiên cứu các hành vi và nhu cầu người dùng để sáng tạo ra các tool phù hợp.
#
# ## Phần kết luận
#
# Với mục tiêu tìm ra các thể loại ứng dụng thu hút nhiều người dùng nhất để tăng lợi nhuận từ quảng bên trong ứng dụng miễn phí, chúng ta đã tìm được 6 thể loại ứng dụng, trong đó ưu tiên hàng đầu là Video or Music, Photography, Book sếp sau cùng là Productivity, Game, Tools. Ngoài ra chúng cũng đã gợi ý sẵn một vài ý tưởng ứng dụng cho các nhà phát triển.
